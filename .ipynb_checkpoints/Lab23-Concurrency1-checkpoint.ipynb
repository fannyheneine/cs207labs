# %%
import sys
sys.version
# Out:
# '3.5.1 |Anaconda 2.4.1 (x86_64)| (default, Dec  7 2015, 11:24:55) \n[GCC 4.2.1 (Apple Inc. build 5577)]'

# %% [markdown]
# ### FUTURES
#
# A future, or promise, is something that represents a pending operation and returns straight away. One can then query their state of completion, or register callbacks to be called on successful completion or error.
#
# Examples Adapted from Fluent Python.

# %%
import time, uuid, functools
def get_thing_maker(secs, item):
    time.sleep(secs)
    return str(uuid.uuid4())+str(item)
get_thing = functools.partial(get_thing_maker, 1)
def get_many(lot):
    counter=0
    for t in lot:
        thing = get_thing(t)
        counter += 1
    return counter
def serial_main(it):
    t0 = time.time()
    count = get_many(it)
    elapsed = time.time() - t0
    msg = '\n{} things got in {:.2f}s' 
    print(msg.format(count, elapsed))

# %% [markdown]
# #### Serial sleeping

# %%
serial_main(range(20))
# Out:
# 20 things got in 20.07s

# %% [markdown]
# #### concurrent sleeping using threads

# %%
from concurrent import futures
def get_many_threaded1(it):
    workers = 10
    with futures.ThreadPoolExecutor(max_workers=workers) as executor:
        res = executor.map(get_thing, it)
    return len(list(res))
def threaded_main1(it):
    t0 = time.time()
    count = get_many_threaded1(it)
    elapsed = time.time() - t0
    msg = '\n{} things got in {:.2f}s' 
    print(msg.format(count, elapsed))

# %%
threaded_main1(range(20))
# Out:
# 20 things got in 2.01s

# %% [markdown]
# One might think that the concurrent IO (or sleeping) case is limited by the GIL, but in both cases, the GIL is yielded. Thus there is no waiting around.
#
# The GIL is harmless if code is being run in the context of python library IO or code running in properly coded C extensions like numpy.  The time.sleep() function also releases the GIL. Python threads are totally usable in I/O-bound applications.

# %% [markdown]
# ### Threads
#
# threads vs processes
#
# On linux
#
# - processes created by fork()
# - have a primary thread
# - thread is the unit of execution
# - process is a container, can have more threads
# - can be scheduled across different cores/cpus
#
# ```c
# int pid;
# int status = 0;
# /* fork returns pid of child to parent and 0 to child*/
# if (pid = fork()) {
#     /* parent code */
#     pid = wait(&status);
#     /*wait returns child pid and status*/
# } else {
#     /* child  code*/
#     exit(status);
# }
# ```
#
# - threads in a process share same address space (share it entirely)
# - thread abstraction decouples resource allocation from control
# - defines a single sequential execution stream with PC, stack, register values
# - process handles: address space, global variables, open files, child processes, pending alarms, signals and signal handlers, accounting info
# - thread handles program counter, registers, stack, and state
# - user vs kernel threads

# %%
def fib(n):
    return fib(n - 1) + fib(n - 2) if n > 1 else n

# %%
from threading import Thread
from time import sleep
from time import time

def sleepy(): #like io
    i=0
    while i < 10:
        print("{} -- {} Sleepy!".format(i, int(time())), flush=True)
        sleep(3)
        i += 1

def cpuy():
    for i in range(35):
        val = fib(i)
        print("fib({}) is {}".format(i, val))

def cpuy2():
    for i in range(35):
        val = fib(i)
        print("cpuy2 fib({}) is {}".format(i, val))
        
def main():
    # Second thread will print the hello message. Starting as a daemon means
    # the thread will not prevent the process from exiting.
    start = time()
    cpuy()
    cpuy2()
    print("serial elapsed:", time() - start)
    start=time()
    #t = Thread(target=sleepy)
    #t.start()
    t2 = Thread(target=cpuy2)
    t2.start()
    # Main thread will read and process input
    cpuy()
    print("thread elapsed:", time() - start)
if __name__ == '__main__':
    main()
# Out:
# fib(0) is 0
# fib(1) is 1
# fib(2) is 1
# fib(3) is 2
# fib(4) is 3
# fib(5) is 5
# fib(6) is 8
# fib(7) is 13
# fib(8) is 21
# fib(9) is 34
# fib(10) is 55
# fib(11) is 89
# fib(12) is 144
# fib(13) is 233
# fib(14) is 377
# fib(15) is 610
# fib(16) is 987
# fib(17) is 1597
# fib(18) is 2584
# fib(19) is 4181
# fib(20) is 6765
# fib(21) is 10946
# fib(22) is 17711
# fib(23) is 28657
# fib(24) is 46368
# fib(25) is 75025
# fib(26) is 121393
# fib(27) is 196418
# fib(28) is 317811
# fib(29) is 514229
# fib(30) is 832040
# fib(31) is 1346269
# fib(32) is 2178309
# fib(33) is 3524578
# fib(34) is 5702887
# cpuy2 fib(0) is 0
# cpuy2 fib(1) is 1
# cpuy2 fib(2) is 1
# cpuy2 fib(3) is 2
# cpuy2 fib(4) is 3
# cpuy2 fib(5) is 5
# cpuy2 fib(6) is 8
# cpuy2 fib(7) is 13
# cpuy2 fib(8) is 21
# cpuy2 fib(9) is 34
# cpuy2 fib(10) is 55
# cpuy2 fib(11) is 89
# cpuy2 fib(12) is 144
# cpuy2 fib(13) is 233
# cpuy2 fib(14) is 377
# cpuy2 fib(15) is 610
# cpuy2 fib(16) is 987
# cpuy2 fib(17) is 1597
# cpuy2 fib(18) is 2584
# cpuy2 fib(19) is 4181
# cpuy2 fib(20) is 6765
# cpuy2 fib(21) is 10946
# cpuy2 fib(22) is 17711
# cpuy2 fib(23) is 28657
# cpuy2 fib(24) is 46368
# cpuy2 fib(25) is 75025
# cpuy2 fib(26) is 121393
# cpuy2 fib(27) is 196418
# cpuy2 fib(28) is 317811
# cpuy2 fib(29) is 514229
# cpuy2 fib(30) is 832040
# cpuy2 fib(31) is 1346269
# cpuy2 fib(32) is 2178309
# cpuy2 fib(33) is 3524578
# cpuy2 fib(34) is 5702887
# serial elapsed: 15.101402997970581
# cpuy2 fib(0) is 0
# cpuy2 fib(1) is 1
# cpuy2 fib(2) is 1
# cpuy2 fib(3) is 2
# cpuy2 fib(4) is 3
# cpuy2 fib(5) is 5
# cpuy2 fib(6) is 8
# cpuy2 fib(7) is 13
# cpuy2 fib(8) is 21
# cpuy2 fib(9) is 34
# cpuy2 fib(10) is 55
# cpuy2 fib(11) is 89
# cpuy2 fib(12) is 144
# cpuy2 fib(13) is 233
# cpuy2 fib(14) is 377
# cpuy2 fib(15) is 610
# cpuy2 fib(16) is 987
# cpuy2 fib(17) is 1597
# fib(0) is 0
# fib(1) is 1
# fib(2) is 1
# fib(3) is 2
# fib(4) is 3
# fib(5) is 5
# fib(6) is 8
# fib(7) is 13
# fib(8) is 21
# fib(9) is 34
# fib(10) is 55
# fib(11) is 89
# fib(12) is 144
# fib(13) is 233
# fib(14) is 377
# fib(15) is 610
# fib(16) is 987
# fib(17) is 1597
# fib(18) is 2584
# cpuy2 fib(18) is 2584
# cpuy2 fib(19) is 4181
# fib(19) is 4181
# fib(20) is 6765
# cpuy2 fib(20) is 6765
# cpuy2 fib(21) is 10946
# fib(21) is 10946
# cpuy2 fib(22) is 17711
# fib(22) is 17711cpuy2 fib(23) is 28657
# cpuy2 fib(24) is 46368
#
# fib(23) is 28657cpuy2 fib(25) is 75025
#
# fib(24) is 46368cpuy2 fib(26) is 121393
#
# fib(25) is 75025cpuy2 fib(27) is 196418
#
# fib(26) is 121393
# cpuy2 fib(28) is 317811
# fib(27) is 196418
# cpuy2 fib(29) is 514229
# fib(28) is 317811
# fib(29) is 514229
# cpuy2 fib(30) is 832040
# fib(30) is 832040
# cpuy2 fib(31) is 1346269
# fib(31) is 1346269
# cpuy2 fib(32) is 2178309
# fib(32) is 2178309
# cpuy2 fib(33) is 3524578
# fib(33) is 3524578
# cpuy2 fib(34) is 5702887
# fib(34) is 5702887
# thread elapsed: 15.902837991714478

# %% [markdown]
# ### Processes with concurrent futures.
#
# CPU based processing wont release the gil, and is thus best done in a separate process. For illustration, we show what this looks like.

# %%
import time
def get_many_process(it, workers=None):
    if workers:
        with futures.ProcessPoolExecutor(max_workers=workers) as executor:
            res = executor.map(get_thing, it)
    else:
        with futures.ProcessPoolExecutor() as executor:
            res = executor.map(get_thing, it)
    return len(list(res))

def process_main(it, workers=None):
    t0 = time.time()
    count = get_many_process(it, workers)
    elapsed = time.time() - t0
    msg = '\n{} things got in {:.2f}s' 
    print(msg.format(count, elapsed))

# %%
process_main(range(20))
# Out:
# 20 things got in 5.09s

# %%
process_main(range(20), workers=10)
# Out:
# 20 things got in 2.12s

# %%
print(__name__)
# Out:
# __main__

# %%
import multiprocessing
start = time.time()
p=multiprocessing.Process(target=cpuy2)
p.start()
cpuy()
p.join()
print("mp elapsed:", time.time() - start)
# Out:
# fib(0) is 0
# fib(1) is 1
# fib(2) is 1
# fib(3) is 2
# fib(4) is 3
# fib(5) is 5
# fib(6) is 8
# fib(7) is 13
# fib(8) is 21
# fib(9) is 34
# fib(10) is 55
# fib(11) is 89
# fib(12) is 144
# fib(13) is 233
# fib(14) is 377
# fib(15) is 610
# fib(16) is 987
# fib(17) is 1597
# fib(18) is 2584
# fib(19) is 4181
# fib(20) is 6765
# fib(21) is 10946
# fib(22) is 17711cpuy2 fib(0) is 0
# cpuy2 fib(1) is 1
# cpuy2 fib(2) is 1
# cpuy2 fib(3) is 2
# cpuy2 fib(4) is 3
# cpuy2 fib(5) is 5
# cpuy2 fib(6) is 8
# cpuy2 fib(7) is 13
# cpuy2 fib(8) is 21
# cpuy2 fib(9) is 34
# cpuy2 fib(10) is 55
# cpuy2 fib(11) is 89
# cpuy2 fib(12) is 144
# cpuy2 fib(13) is 233
# cpuy2 fib(14) is 377
# cpuy2 fib(15) is 610
# cpuy2 fib(16) is 987
# cpuy2 fib(17) is 1597
# cpuy2 fib(18) is 2584
# cpuy2 fib(19) is 4181
#
# fib(23) is 28657cpuy2 fib(20) is 6765
# cpuy2 fib(21) is 10946
#
# fib(24) is 46368cpuy2 fib(22) is 17711
# cpuy2 fib(23) is 28657
#
# fib(25) is 75025cpuy2 fib(24) is 46368
#
# fib(26) is 121393cpuy2 fib(25) is 75025
#
# fib(27) is 196418cpuy2 fib(26) is 121393
#
# fib(28) is 317811cpuy2 fib(27) is 196418
# cpuy2 fib(28) is 317811
#
# fib(29) is 514229
# fib(30) is 832040cpuy2 fib(29) is 514229
# cpuy2 fib(30) is 832040
#
# fib(31) is 1346269
# fib(32) is 2178309cpuy2 fib(31) is 1346269
# cpuy2 fib(32) is 2178309
#
# fib(33) is 3524578
# fib(34) is 5702887cpuy2 fib(33) is 3524578
# cpuy2 fib(34) is 5702887
#
# mp elapsed: 13.282005071640015

# %%
# input('>')

# %% [markdown]
# ### sockets
#
# - distinction between "client socket" and "server socket"
# - default `socket.socket(family=AF_INET, type=SOCK_STREAM, proto=0, fileno=None)`
# - server socket sits and creates client sockets
# - non-blocking sockets and the `select` system call
#
# Read: https://docs.python.org/3.5/howto/sockets.html

# %% [markdown]
# ### Writing a web page fetcher
#
# We'll eventually use the asyncio module to play with web page fetching and crawling, but lets build up to that by writing a simple fetcher. We'll start with blocking, then move to non-blocking, and finally to co-routines, and even more finally to `yield from` based co-routines.
#
# Adapted from http://aosabook.org/en/500L/a-web-crawler-with-asyncio-coroutines.html

# %% [markdown]
# #### Blocking fetch

# %%
import socket
def fetch(host, url):
    sock = socket.socket()
    sock.connect((host, 80))
    request = 'GET {} HTTP/1.0\r\nHost: {}\r\n\r\n'.format(url, host)
    sock.send(request.encode('ascii'))
    response = b''
    chunk = sock.recv(4096)
    while chunk:
        response += chunk
        chunk = sock.recv(4096)
    return response

# %%
from IPython.display import HTML, IFrame
HTML(str(fetch("www.example.com","/")))
# Out:
# b'HTTP/1.0 200 OK\r\nCache-Control: max-age=604800\r\nContent-Type: text/html\r\nDate: Sun, 03 Apr 2016 17:50:23 GMT\r\nEtag: "359670651+gzip+ident"\r\nExpires: Sun, 10 Apr 2016 17:50:23 GMT\r\nLast-Modified: Fri, 09 Aug 2013 23:54:35 GMT\r\nServer: ECS (bos/F56E)\r\nVary: Accept-Encoding\r\nX-Cache: HIT\r\nx-ec-custom-error: 1\r\nContent-Length: 1270\r\nConnection: close\r\n\r\n<!doctype html>\n<html>\n<head>\n    <title>Example Domain</title>\n\n    <meta charset="utf-8" />\n    <meta http-equiv="Content-type" content="text/html; charset=utf-8" />\n    <meta name="viewport" content="width=device-width, initial-scale=1" />\n    <style type="text/css">\n    body {\n        background-color: #f0f0f2;\n        margin: 0;\n        padding: 0;\n        font-family: "Open Sans", "Helvetica Neue", Helvetica, Arial, sans-serif;\n        \n    }\n    div {\n        width: 600px;\n        margin: 5em auto;\n        padding: 50px;\n        background-color: #fff;\n        border-radius: 1em;\n    }\n    a:link, a:visited {\n        color: #38488f;\n        text-decoration: none;\n    }\n    @media (max-width: 700px) {\n        body {\n            background-color: #fff;\n        }\n        div {\n            width: auto;\n            margin: 0 auto;\n            border-radius: 0;\n            padding: 1em;\n        }\n    }\n    </style>    \n</head>\n\n<body>\n<div>\n    <h1>Example Domain</h1>\n    <p>This domain is established to be used for illustrative examples in documents. You may use this\n    domain in examples without prior coordination or asking for permission.</p>\n    <p><a href="http://www.iana.org/domains/example">More information...</a></p>\n</div>\n</body>\n</html>\n'

# %% [markdown]
# #### Basic non-blocking

# %%
host="www.example.com"
url="/"
request = 'GET {} HTTP/1.0\r\nHost: {}\r\n\r\n'.format(url, host)
encoded = request.encode('ascii')
sock = socket.socket()
sock.setblocking(False)
try:
    sock.connect(('xkcd.com', 80))
except BlockingIOError:
    pass
while True:
    try:
        sock.send(encoded)
        break  # Done.
    except OSError as e:
        pass

print('sent')
# Out:
# sent

# %% [markdown]
# This has only been implemented partially. Notice how the `sock.send` spins in a loop.
#
# This eats cycles. the solution is to use select/kqueue/epoll from a small number of connections to a large number of them. The basic idea behind `select` is to wait for an event to occur on a small set of non-blocking sokets.
#
# We'll use python's `DefaultSelector`, an addition from python 3.4 that automatically chooses the "best" select like implementation on your system.

# %%
from selectors import DefaultSelector, EVENT_WRITE
from time import time
selector = DefaultSelector()
host="www.example.com"
sock = socket.socket()
sock.setblocking(False)
try:
    sock.connect((host, 80))
except BlockingIOError:
    pass

def connected():
    selector.unregister(sock.fileno())
    print('connected!', flush=True)

selector.register(sock.fileno(), EVENT_WRITE, connected)
# Out:
# SelectorKey(fileobj=77, fd=77, events=2, data=<function connected at 0x104d5ff28>)

# %% [markdown]
# `connected` is the **callback** run when the connection happens.

# %%
def loop():
    start = time()
    while True:
        if time() - start > 10:
            break
        events = selector.select()
        for event_key, event_mask in events:
            callback = event_key.data
            callback()

# %% [markdown]
# Such a loop is called an "event loop". An async frameworkhas two parts: (a) such an event loop and (b) non-blocking sockets. It all runs on one thread. This is a system, it should be obvious for I/O bound problems.
#
# What have we demonstrated already? We showed how to begin an operation and execute a callback when the operation is ready. An async framework builds on the two features we have shown—non-blocking sockets and the event loop—to run concurrent operations on a single thread.
#
# Guido:
# >We have achieved "concurrency" here, but not what is traditionally called "parallelism". What asynchronous I/O is right for, is applications with many slow or sleepy connections with infrequent events.

# %%
loop() #loop will destruct after 10 secs
# Out:
# connected!

# %% [markdown]
# #### async with response reading

# %%
from selectors import DefaultSelector, EVENT_READ, EVENT_WRITE

selector = DefaultSelector()
class Fetcher:
    def __init__(self, host, url, level=0):
        self.response = b''  # Empty array of bytes.
        self.host = host
        self.url = url
        self.sock = None
        
    # Method on Fetcher class.
    def fetch(self):
        self.sock = socket.socket()
        self.sock.setblocking(False)
        try:
            self.sock.connect((self.host, 80))
        except BlockingIOError:
            pass

        # Register next callback.
        selector.register(self.sock.fileno(),
                          EVENT_WRITE,
                          self.connected)

    def connected(self, key, mask):
        print('connected!', flush=True)
        selector.unregister(key.fd)
        request = 'GET {} HTTP/1.0\r\nHost: {}\r\n\r\n'.format(self.url, self.host)
        self.sock.send(request.encode('ascii'))

        # Register the next callback.
        selector.register(key.fd,
                          EVENT_READ,
                          self.read_response)
        
    def read_response(self, key, mask):
        global stopped
        
        chunk = self.sock.recv(128)  # USUALLY 4k chunk size, here small
        if chunk:
            print("read chunk", flush=True)
            self.response += chunk
        else:
            print("all read", flush=True)
            selector.unregister(key.fd)  # Done reading.
            stopped=True
            
stopped = False

def loop():
    while not stopped:
        events = selector.select()
        for event_key, event_mask in events:
            callback = event_key.data
            callback(event_key, event_mask)
        #do fibonacci

# %%
fetcher = Fetcher('xkcd.com', '/353/')
fetcher.fetch()
loop()
# Out:
# connected!
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# all read

# %% [markdown]
# You can see how the control-flow is chained together by having the connected callback do the resposing. Beyond a 2-3 ladder, this gets confusing and onerous (see some node.js code). As compared to a blocking program, where the continuation of the program is stored and adressed via the instruction pointer in a sequential fashiom, here the cintinuation is stored by registering the callbacks.'
#
# Since the current frame is popped out of the stack, exceptions have a hard time figuring the origin This is called stack-ripping.
#
# So, even apart from the long debate about the relative efficiencies of multithreading and async, there is this other debate regarding which is more error-prone: threads are susceptible to data races if you make a mistake synchronizing them, but callbacks are stubborn to debug due to stack ripping. And within a bit, we get callback soup.
#
# https://thesynchronousblog.wordpress.com/tag/stack-ripping/
#
# Threads seem to offer a more natural way of programming as the programmer with all state in thread’s single stack.

# %% [markdown]
# So why not use them. As we said last time: synchronization and overhead.
#
# But we can do better with Coroutines!
#
# Guido:
# >We entice you with a promise. It is possible to write asynchronous code that combines the efficiency of callbacks with the classic good looks of multithreaded programming. This combination is achieved with a pattern called "coroutines". Using Python 3.4's standard asyncio library, and a package called "aiohttp", fetching a URL in a coroutine is very direct7:
#
#     @asyncio.coroutine
#     def fetch(self, url):
#         response = yield from self.session.get(url)
#         body = yield from response.read()
#
# In 3.5 its even more clear:
#
# async def fetch(self, url):
#         response = await self.session.get(url)
#         body = await response.read()

# %% [markdown]
# ### Back to the Future with co-routines

# %%
from selectors import DefaultSelector, EVENT_READ, EVENT_WRITE
import socket
selector = DefaultSelector()

# %% [markdown]
# The future, as you might expect is something with callbacks...

# %%
class MyFuture:
    def __init__(self):
        self.result = None
        self._callbacks = []

    def add_done_callback(self, fn):
        self._callbacks.append(fn)

    def set_result(self, result):
        self.result = result
        for fn in self._callbacks:
            fn(self)

# %% [markdown]
# We need a "main" to yield to.

# %%
class Fetcher:
    
    def __init__(self, url, host):
        self.url = url
        self.host = host
        self.response = b''  # Empty array of bytes.

        
    def fetch(self):
        global stopped
        sock = socket.socket()

        sock.setblocking(False)
        try:
            sock.connect((self.host, 80))
        except BlockingIOError:
            pass

        f = MyFuture()

        #resolves the future by setting a result on it
        def on_connected():
            print('on connected cb ran', flush=True)
            f.set_result(None)
        
        
        
        selector.register(sock.fileno(),
                          EVENT_WRITE,
                          on_connected)
        print("about to yield connection future", flush=True)
        yield f#this makes it look like fetch has returned the "future"
        #bit we have not lost the state (or have to have carried it in obj)
        #a send in will continue us here
        print('we were connected! now back in gen', flush=True)
        selector.unregister(sock.fileno())
        request = 'GET {} HTTP/1.0\r\nHost: {}\r\n\r\n'.format(self.url, self.host)
        sock.send(request.encode('ascii'))
        while True:
            print("in loop")
            #now create a new future for the data-recieving call
            f = MyFuture()
            def on_response():
                chunky = sock.recv(4096)  # 4k chunk size.
                f.set_result(chunky)
            selector.register(sock.fileno(),
                              EVENT_READ,
                              on_response)
            #now to restart the gen, we will from the main
            #throw the data right back in
            chunk = yield f
            selector.unregister(sock.fileno())
            if chunk:
                print("len(chunk)",len(chunk))
                self.response += chunk
            else:
                print("all read")
                stopped= True
                break

# %%
#But when the future resolves, what resumes the generator? We need a coroutine driver. Let us call it "task":
#(this is our main)
class Task:
    def __init__(self, coro):
        self.coro = coro
        f = MyFuture()
        print(">>sending none to initial future",f)
        f.set_result(None)
        print("...stepping")
        self.step(f)
        print(">>>after priming")

    def step(self, future):
        try:
            print("sending", type(future.result))
            next_future = self.coro.send(future.result)
            print('got next future', next_future)

        except StopIteration:
            print("si")
            return None
        next_future.add_done_callback(self.step)

# %%
stopped=False
def loop():
    while not stopped:
        events = selector.select()
        for event_key, event_mask in events:
            callback = event_key.data
            callback()

# %%
fetcher = Fetcher('/353/', 'xkcd.com')
Task(fetcher.fetch())
stopped=False
loop()
# Out:
# >>sending none to initial future <__main__.MyFuture object at 0x104d50dd8>
# ...stepping
# sending <class 'NoneType'>
# about to yield connection future
# got next future <__main__.MyFuture object at 0x104d50cc0>
# >>>after priming
# on connected cb ran
# sending <class 'NoneType'>
# we were connected! now back in gen
# in loop
# got next future <__main__.MyFuture object at 0x104d72ac8>
# sending <class 'bytes'>
# len(chunk) 2768
# in loop
# got next future <__main__.MyFuture object at 0x104d585f8>
# sending <class 'bytes'>
# len(chunk) 4096
# in loop
# got next future <__main__.MyFuture object at 0x104d582e8>
# sending <class 'bytes'>
# len(chunk) 511
# in loop
# got next future <__main__.MyFuture object at 0x104d58208>
# sending <class 'bytes'>
# all read
# si

# %% [markdown]
# #### Refactoring using generators

# %%
#But when the future resolves, what resumes the generator? We need a coroutine driver. Let us call it "task":
#(this is our main)
class Task:
    def __init__(self, coro):
        self.coro = coro
        f = MyFuture()
        print(">>sending none to initial future",f)
        f.set_result(None)
        print("...stepping")
        self.step(f)
        print(">>>after priming")

    def step(self, future):
        try:
            print("sending", type(future.result))
            next_future = self.coro.send(future.result)
            print('got next future', next_future)

        except StopIteration:
            print("si")
            return None
        next_future.add_done_callback(self.step)

# %%
def read(sock):
    f = MyFuture()

    def on_readable():
        f.set_result(sock.recv(4096))

    selector.register(sock.fileno(), EVENT_READ, on_readable)
    chunk = yield f  # Read one chunk.
    selector.unregister(sock.fileno())
    return chunk

# %%
def read_all(sock):
    global stopped
    response = []
    # Read whole response.
    chunk = yield from read(sock)
    while chunk:
        response.append(chunk)
        chunk = yield from read(sock)
    stopped=True
    return b''.join(response)

# %% [markdown]
# >If you squint and make the yield from statements disappear it looks like  conventional functions doing blocking I/O. But in fact, read and read_all are coroutines. Yielding from read pauses read_all until the I/O completes. While read_all is paused, asyncio's event loop does other work and awaits other I/O events; read_all is resumed with the result of read on the next loop tick once its event is ready.

# %%
class Fetcher:
    
    def __init__(self, url, host):
        self.url = url
        self.host = host
        self.response = b''  # Empty array of bytes.

        
    def fetch(self):
        global stopped
        sock = socket.socket()

        sock.setblocking(False)
        try:
            sock.connect((host, 80))
        except BlockingIOError:
            pass

        f = MyFuture()

        def on_connected():
            print('on connected cb ran')
            f.set_result(None)
        
        
        
        selector.register(sock.fileno(),
                          EVENT_WRITE,
                          on_connected)
        print("about to yield connection future")
        yield f
        print('connected!')
        selector.unregister(sock.fileno())
        request = 'GET {} HTTP/1.0\r\nHost: xkcd.com\r\n\r\n'.format(self.url)
        sock.send(request.encode('ascii'))
        yield from read_all(sock)

# %%
fetcher = Fetcher('/353/', 'xkcd.com')
Task(fetcher.fetch())
stopped = False
loop()
# Out:
# >>sending none to initial future <__main__.MyFuture object at 0x104d98198>
# ...stepping
# sending <class 'NoneType'>
# about to yield connection future
# got next future <__main__.MyFuture object at 0x104d98208>
# >>>after priming
# on connected cb ran
# sending <class 'NoneType'>
# connected!
# got next future <__main__.MyFuture object at 0x104d98240>
# sending <class 'bytes'>
# got next future <__main__.MyFuture object at 0x104d981d0>
# sending <class 'bytes'>
# si

# %% [markdown]
# ![](http://aosabook.org/en/500L/crawler-images/yield-from.png)
#
# There is one yield left amongst the yield froms. For consistency, this can be fixed...it also lets us change implementations under the hood..

# %%
def read(sock):
    f = MyFuture()

    def on_readable():
        f.set_result(sock.recv(4096))

    selector.register(sock.fileno(), EVENT_READ, on_readable)
    chunk = yield from f  # Read one chunk.
    selector.unregister(sock.fileno())
    return chunk

# %%
class MyFuture:
    def __init__(self):
        self.result = None
        self._callbacks = []

    def add_done_callback(self, fn):
        self._callbacks.append(fn)

    def set_result(self, result):
        self.result = result
        print("cblist", self._callbacks)
        for fn in self._callbacks:
            fn(self)
            
    def __iter__(self):
        yield self
        return self.result

# %%
class Fetcher:
    
    def __init__(self, url, host):
        self.url = url
        self.host = host
        self.response = b''  # Empty array of bytes.

        
    def fetch(self):
        global stopped
        sock = socket.socket()

        sock.setblocking(False)
        try:
            sock.connect((self.host, 80))
        except BlockingIOError:
            pass

        f = MyFuture()

        def on_connected():
            print('on connected cb ran')
            f.set_result(None)
        
        
        
        selector.register(sock.fileno(),
                          EVENT_WRITE,
                          on_connected)
        print("about to yield connection future")
        yield from f
        print('connected!')
        selector.unregister(sock.fileno())
        request = 'GET {} HTTP/1.0\r\nHost: xkcd.com\r\n\r\n'.format(self.url)
        sock.send(request.encode('ascii'))
        yield from read_all(sock)

# %%
fetcher = Fetcher('/353/','xkcd.com')
Task(fetcher.fetch())
stopped = False
loop()
# Out:
# >>sending none to initial future <__main__.MyFuture object at 0x104d72ef0>
# cblist []
# ...stepping
# sending <class 'NoneType'>
# about to yield connection future
# got next future <__main__.MyFuture object at 0x104d722e8>
# >>>after priming
# on connected cb ran
# cblist [<bound method Task.step of <__main__.Task object at 0x104d72240>>]
# sending <class 'NoneType'>
# connected!
# got next future <__main__.MyFuture object at 0x104d72160>
# cblist [<bound method Task.step of <__main__.Task object at 0x104d72240>>]
# sending <class 'bytes'>
# got next future <__main__.MyFuture object at 0x104d72ac8>
# cblist [<bound method Task.step of <__main__.Task object at 0x104d72240>>]
# sending <class 'bytes'>
# got next future <__main__.MyFuture object at 0x104d72710>
# cblist [<bound method Task.step of <__main__.Task object at 0x104d72240>>]
# sending <class 'bytes'>
# got next future <__main__.MyFuture object at 0x104d72160>
# cblist [<bound method Task.step of <__main__.Task object at 0x104d72240>>]
# sending <class 'bytes'>
# got next future <__main__.MyFuture object at 0x104d72ac8>
# cblist [<bound method Task.step of <__main__.Task object at 0x104d72240>>]
# sending <class 'bytes'>
# si

# %% [markdown]
# ## Lab
#
# Implement a URL fetcher using Beautiful Soup in the callback version. We will implement a similar one using coroutines on wednesday.
#
# The implementation will extend the read_response method by parsing for URL's using `bs4` . Start by creating globals:
# ```
# urls_todo = set(['/'])
# seen_urls = set(['/'])
# ```
#
# then:
#
# ```
# links = self.parse_links()#write this
# ```
# (using self.response)
#
# Then use the set `difference` method  to add new links to `urls_todo` and recursively set up a `Fetcher` instance.
#
# Now update the `seen_urls` and `urls_todo` thus:
# ```
# seen_urls.update(links)
# urls_todo.remove(self.url)
# if not urls_todo:
#     stopped = True
# ```

# %%
from bs4 import BeautifulSoup

# %%
# Technically, this class should inherit from the previous Fetcher class,
# but this made it easier to go through the code in detail.
class FetcherBS:

    # same as code above
    def __init__(self, host, url, level=0):
        self.response = b''  # empty array of bytes
        self.host = host
        self.url = url
        self.sock = None
        
    # same as code above
    def fetch(self):
        self.sock = socket.socket()
        self.sock.setblocking(False)
        try:
            self.sock.connect((self.host, 80))
        except BlockingIOError:
            pass

        # register next callback
        selector.register(self.sock.fileno(),
                          EVENT_WRITE,
                          self.connected)

    # same as code above
    def connected(self, key, mask):
        print('Connected     >>  ' + self.host + self.url, flush=True)
        selector.unregister(key.fd)
        request = 'GET {} HTTP/1.0\r\nHost: {}\r\n\r\n'.format(self.url, self.host)
        self.sock.send(request.encode('ascii'))

        # register the next callback
        selector.register(key.fd,
                          EVENT_READ,
                          self.read_response)
        
    # extended to parse for urls using bs4
    def read_response(self, key, mask):
        
        global stopped
        global urls_todo # added
        global seen_urls # added
                
        chunk = self.sock.recv(128)  # USUALLY 4k chunk size, here small
        
        if chunk:
            # too much output!
#             print('read ' + self.url, flush=True)
            self.response += chunk
        else:
            
            # remove url from to-do list
            if self.url in urls_todo:
                urls_todo.remove(self.url)

                print('Disconnected  >>  ' + self.host + self.url, flush=True)
            selector.unregister(key.fd) # done reading
            
            # parse for urls
            links = self.parse_links()
            
            # use set difference method to add new links to urls_todo
            # that have not already been seen, then recursively set up
            # the fetcher instance
            for link in links.difference(seen_urls):
                urls_todo.add(link)
                FetcherBS(self.host, link).fetch()

            # update list of seen urls
            seen_urls.update(links)            
            
            # stop when we run out of urls to parse
            if not urls_todo:
                stopped = True
            
    # new function to parse links in each webpage
    def parse_links(self):
        soup = BeautifulSoup(self.response, 'html.parser')
        link_list_details = soup.find_all('a', href=True)
        link_list_href = [l['href'] for l in link_list_details]
        # drop external (non-xkcd) links to keep this manageable
        link_list_href = [l for l in link_list_href if l[0]=='/']
        return set(link_list_href)

# %%
# same as code above
def loop():
    while not stopped:
        events = selector.select()
        for event_key, event_mask in events:
            callback = event_key.data
            callback(event_key, event_mask)

# %%
selector = DefaultSelector()
stopped = False

urls_todo = set(['/'])
seen_urls = set(['/'])

fetcher = FetcherBS('xkcd.com', '/')
fetcher.fetch()
loop()
# Out:
# Connected     >>  xkcd.com/
# Disconnected  >>  xkcd.com/
# Connected     >>  xkcd.com//c.xkcd.com/random/comic/
# Connected     >>  xkcd.com/atom.xml
# Connected     >>  xkcd.com/rss.xml
# Connected     >>  xkcd.com/archive
# Connected     >>  xkcd.com/1661/
# Connected     >>  xkcd.com/1/
# Connected     >>  xkcd.com/license.html
# Connected     >>  xkcd.com/about
# Disconnected  >>  xkcd.com//c.xkcd.com/random/comic/
# Disconnected  >>  xkcd.com/archive
# Disconnected  >>  xkcd.com/rss.xml
# Disconnected  >>  xkcd.com/atom.xml
# Disconnected  >>  xkcd.com/about
# Disconnected  >>  xkcd.com/license.html
# Disconnected  >>  xkcd.com/1661/
# Disconnected  >>  xkcd.com/1/
# Connected     >>  xkcd.com/1660/
# Connected     >>  xkcd.com/1662/
# Connected     >>  xkcd.com/2/
# Disconnected  >>  xkcd.com/1660/
# Disconnected  >>  xkcd.com/1662/
# Connected     >>  xkcd.com/1659/
# Disconnected  >>  xkcd.com/2/
# Disconnected  >>  xkcd.com/1659/
# Connected     >>  xkcd.com/3/
# Connected     >>  xkcd.com/1658/
# Disconnected  >>  xkcd.com/3/
# Disconnected  >>  xkcd.com/1658/
# Connected     >>  xkcd.com/4/
# Connected     >>  xkcd.com/1657/
# Disconnected  >>  xkcd.com/4/
# Disconnected  >>  xkcd.com/1657/
# Connected     >>  xkcd.com/5/
# Connected     >>  xkcd.com/1656/
# Disconnected  >>  xkcd.com/5/
# Disconnected  >>  xkcd.com/1656/
# Connected     >>  xkcd.com/6/
# Connected     >>  xkcd.com/1655/
# Disconnected  >>  xkcd.com/6/
# Disconnected  >>  xkcd.com/1655/
# Connected     >>  xkcd.com/7/
# Connected     >>  xkcd.com/1654/
# Disconnected  >>  xkcd.com/7/
# Connected     >>  xkcd.com/8/
# Disconnected  >>  xkcd.com/1654/
# Disconnected  >>  xkcd.com/8/
# Connected     >>  xkcd.com/1653/
# Connected     >>  xkcd.com/9/
# Disconnected  >>  xkcd.com/1653/
# Disconnected  >>  xkcd.com/9/
# Connected     >>  xkcd.com/1652/
# Connected     >>  xkcd.com/10/
# Disconnected  >>  xkcd.com/1652/
# Disconnected  >>  xkcd.com/10/
# Connected     >>  xkcd.com/1651/
# Connected     >>  xkcd.com/11/
# Disconnected  >>  xkcd.com/1651/
# Disconnected  >>  xkcd.com/11/
# Connected     >>  xkcd.com/1650/
# Connected     >>  xkcd.com/12/
# Disconnected  >>  xkcd.com/1650/
# Disconnected  >>  xkcd.com/12/
# Connected     >>  xkcd.com/1649/
# Connected     >>  xkcd.com/13/
# Disconnected  >>  xkcd.com/1649/
# Disconnected  >>  xkcd.com/13/
# Connected     >>  xkcd.com/1648/
# Connected     >>  xkcd.com/14/
# Disconnected  >>  xkcd.com/14/
# Disconnected  >>  xkcd.com/1648/
# Connected     >>  xkcd.com/15/
# Connected     >>  xkcd.com/1647/
# Disconnected  >>  xkcd.com/15/
# Disconnected  >>  xkcd.com/1647/
# Connected     >>  xkcd.com/16/
# Connected     >>  xkcd.com/1646/
# Disconnected  >>  xkcd.com/16/
# Disconnected  >>  xkcd.com/1646/
# Connected     >>  xkcd.com/17/
# Connected     >>  xkcd.com/1645/
# Disconnected  >>  xkcd.com/17/
# Disconnected  >>  xkcd.com/1645/
# Connected     >>  xkcd.com/18/
# Connected     >>  xkcd.com/1644/
# Disconnected  >>  xkcd.com/18/
# Disconnected  >>  xkcd.com/1644/
# Connected     >>  xkcd.com/19/
# Connected     >>  xkcd.com/1643/
# Disconnected  >>  xkcd.com/19/
# Disconnected  >>  xkcd.com/1643/
# Connected     >>  xkcd.com/20/
# Connected     >>  xkcd.com/1642/
# Disconnected  >>  xkcd.com/20/
# Disconnected  >>  xkcd.com/1642/
# Connected     >>  xkcd.com/21/
# Connected     >>  xkcd.com/1641/
# Disconnected  >>  xkcd.com/21/
# Disconnected  >>  xkcd.com/1641/
# Connected     >>  xkcd.com/22/
# Connected     >>  xkcd.com/1640/
# Disconnected  >>  xkcd.com/22/
# Disconnected  >>  xkcd.com/1640/
# Connected     >>  xkcd.com/23/
# Connected     >>  xkcd.com/1639/
# Disconnected  >>  xkcd.com/23/
# Disconnected  >>  xkcd.com/1639/
# Connected     >>  xkcd.com/24/
# Connected     >>  xkcd.com/1638/
# Disconnected  >>  xkcd.com/24/
# Disconnected  >>  xkcd.com/1638/
# Connected     >>  xkcd.com/25/
# Connected     >>  xkcd.com/1637/
# Disconnected  >>  xkcd.com/25/
# Disconnected  >>  xkcd.com/1637/
# Connected     >>  xkcd.com/26/
# Connected     >>  xkcd.com/1636/
# Disconnected  >>  xkcd.com/26/
# Connected     >>  xkcd.com/27/
# Disconnected  >>  xkcd.com/1636/
# Disconnected  >>  xkcd.com/27/
# Connected     >>  xkcd.com/1635/
# Connected     >>  xkcd.com/28/
# Disconnected  >>  xkcd.com/1635/
# Disconnected  >>  xkcd.com/28/
# Connected     >>  xkcd.com/1634/
# Connected     >>  xkcd.com/29/
# Disconnected  >>  xkcd.com/1634/
# Disconnected  >>  xkcd.com/29/
# Connected     >>  xkcd.com/1633/
# Connected     >>  xkcd.com/30/
# Disconnected  >>  xkcd.com/1633/
# Disconnected  >>  xkcd.com/30/
# Connected     >>  xkcd.com/1632/
# Connected     >>  xkcd.com/31/
# Disconnected  >>  xkcd.com/1632/
# Disconnected  >>  xkcd.com/31/
# Connected     >>  xkcd.com/1631/
# Connected     >>  xkcd.com/32/
# Disconnected  >>  xkcd.com/1631/
# Disconnected  >>  xkcd.com/32/
# Connected     >>  xkcd.com/1630/
# Connected     >>  xkcd.com/33/
# Disconnected  >>  xkcd.com/1630/
# Disconnected  >>  xkcd.com/33/
# Connected     >>  xkcd.com/1629/
# Connected     >>  xkcd.com/34/
# Disconnected  >>  xkcd.com/1629/
# Disconnected  >>  xkcd.com/34/
# Connected     >>  xkcd.com/1628/
# Connected     >>  xkcd.com/35/
# Disconnected  >>  xkcd.com/1628/
# Disconnected  >>  xkcd.com/35/
# Connected     >>  xkcd.com/1627/
# Connected     >>  xkcd.com/36/
# Disconnected  >>  xkcd.com/1627/
# Disconnected  >>  xkcd.com/36/
# Connected     >>  xkcd.com/1626/
# Connected     >>  xkcd.com/37/
# Disconnected  >>  xkcd.com/1626/
# Disconnected  >>  xkcd.com/37/
# Connected     >>  xkcd.com/1625/
# Connected     >>  xkcd.com/38/
# Disconnected  >>  xkcd.com/1625/
# Disconnected  >>  xkcd.com/38/
# Connected     >>  xkcd.com/1624/
# Connected     >>  xkcd.com/39/
# Disconnected  >>  xkcd.com/1624/
# Disconnected  >>  xkcd.com/39/
# Connected     >>  xkcd.com/1623/
# Connected     >>  xkcd.com/40/
# Disconnected  >>  xkcd.com/1623/
# Disconnected  >>  xkcd.com/40/
# Connected     >>  xkcd.com/1622/
# Connected     >>  xkcd.com/41/
# Disconnected  >>  xkcd.com/1622/
# Disconnected  >>  xkcd.com/41/
# Connected     >>  xkcd.com/1621/
# Connected     >>  xkcd.com/42/
# Disconnected  >>  xkcd.com/1621/
# Disconnected  >>  xkcd.com/42/
# Connected     >>  xkcd.com/1620/
# Connected     >>  xkcd.com/43/
# Disconnected  >>  xkcd.com/1620/
# Disconnected  >>  xkcd.com/43/
# Connected     >>  xkcd.com/1619/
# Connected     >>  xkcd.com/44/
# Disconnected  >>  xkcd.com/1619/
# Disconnected  >>  xkcd.com/44/
# Connected     >>  xkcd.com/1618/
# Connected     >>  xkcd.com/45/
# Disconnected  >>  xkcd.com/1618/
# Disconnected  >>  xkcd.com/45/
# Connected     >>  xkcd.com/1617/
# Connected     >>  xkcd.com/46/
# Disconnected  >>  xkcd.com/1617/
# Disconnected  >>  xkcd.com/46/
# Connected     >>  xkcd.com/1616/
# Connected     >>  xkcd.com/47/
# Disconnected  >>  xkcd.com/1616/
# Disconnected  >>  xkcd.com/47/
# Connected     >>  xkcd.com/1615/
# Connected     >>  xkcd.com/48/
# Disconnected  >>  xkcd.com/1615/
# Disconnected  >>  xkcd.com/48/
# Connected     >>  xkcd.com/1614/
# Connected     >>  xkcd.com/49/
# Disconnected  >>  xkcd.com/1614/
# Disconnected  >>  xkcd.com/49/
# Connected     >>  xkcd.com/1613/
# Connected     >>  xkcd.com/50/
# Disconnected  >>  xkcd.com/1613/
# Disconnected  >>  xkcd.com/50/
# Connected     >>  xkcd.com/1612/
# Connected     >>  xkcd.com/51/
# Disconnected  >>  xkcd.com/1612/
# Disconnected  >>  xkcd.com/51/
# Connected     >>  xkcd.com/1611/
# Connected     >>  xkcd.com/52/
# Disconnected  >>  xkcd.com/1611/
# Disconnected  >>  xkcd.com/52/
# Connected     >>  xkcd.com/1610/
# Connected     >>  xkcd.com/53/
# Disconnected  >>  xkcd.com/1610/
# Disconnected  >>  xkcd.com/53/
# Connected     >>  xkcd.com/1609/
# Connected     >>  xkcd.com/54/
# Disconnected  >>  xkcd.com/1609/
# Disconnected  >>  xkcd.com/54/
# Connected     >>  xkcd.com/1608/
# Connected     >>  xkcd.com/55/
# Disconnected  >>  xkcd.com/1608/
# Disconnected  >>  xkcd.com/55/
# Connected     >>  xkcd.com/1607/
# Connected     >>  xkcd.com/56/
# Disconnected  >>  xkcd.com/1607/
# Disconnected  >>  xkcd.com/56/
# Connected     >>  xkcd.com/1606/
# Connected     >>  xkcd.com/57/
# Disconnected  >>  xkcd.com/1606/
# Disconnected  >>  xkcd.com/57/
# Connected     >>  xkcd.com/1605/
# Connected     >>  xkcd.com/58/
# Disconnected  >>  xkcd.com/1605/
# Disconnected  >>  xkcd.com/58/
# Connected     >>  xkcd.com/1604/
# Connected     >>  xkcd.com/59/
# Disconnected  >>  xkcd.com/1604/
# Disconnected  >>  xkcd.com/59/
# Connected     >>  xkcd.com/1603/
# Connected     >>  xkcd.com/60/
# Disconnected  >>  xkcd.com/1603/
# Disconnected  >>  xkcd.com/60/
# Connected     >>  xkcd.com/1602/
# Connected     >>  xkcd.com/61/
# Disconnected  >>  xkcd.com/1602/
# Disconnected  >>  xkcd.com/61/
# Connected     >>  xkcd.com/1601/
# Connected     >>  xkcd.com/62/
# Disconnected  >>  xkcd.com/1601/
# Disconnected  >>  xkcd.com/62/
# Connected     >>  xkcd.com/1600/
# Connected     >>  xkcd.com/63/
# Disconnected  >>  xkcd.com/1600/
# Disconnected  >>  xkcd.com/63/
# Connected     >>  xkcd.com/1599/
# Connected     >>  xkcd.com/64/
# Disconnected  >>  xkcd.com/1599/
# Disconnected  >>  xkcd.com/64/
# Connected     >>  xkcd.com/1598/
# Connected     >>  xkcd.com/65/
# Disconnected  >>  xkcd.com/1598/
# Disconnected  >>  xkcd.com/65/
# Connected     >>  xkcd.com/1597/
# Connected     >>  xkcd.com/66/
# Disconnected  >>  xkcd.com/1597/
# Disconnected  >>  xkcd.com/66/
# Connected     >>  xkcd.com/1596/
# Connected     >>  xkcd.com/67/
# Disconnected  >>  xkcd.com/1596/
# Disconnected  >>  xkcd.com/67/
# Connected     >>  xkcd.com/1595/
# Connected     >>  xkcd.com/68/
# Disconnected  >>  xkcd.com/1595/
# Disconnected  >>  xkcd.com/68/
# Connected     >>  xkcd.com/1594/
# Connected     >>  xkcd.com/69/
# Disconnected  >>  xkcd.com/1594/
# Disconnected  >>  xkcd.com/69/
# Connected     >>  xkcd.com/1593/
# Connected     >>  xkcd.com/70/
# Disconnected  >>  xkcd.com/1593/
# Disconnected  >>  xkcd.com/70/
# Connected     >>  xkcd.com/1592/
# Connected     >>  xkcd.com/71/
# Disconnected  >>  xkcd.com/1592/
# Disconnected  >>  xkcd.com/71/
# Connected     >>  xkcd.com/1591/
# Connected     >>  xkcd.com/72/
# Disconnected  >>  xkcd.com/1591/
# Disconnected  >>  xkcd.com/72/
# Connected     >>  xkcd.com/1590/
# Connected     >>  xkcd.com/73/
# Disconnected  >>  xkcd.com/1590/
# Disconnected  >>  xkcd.com/73/
# Connected     >>  xkcd.com/1589/
# Connected     >>  xkcd.com/74/
# Disconnected  >>  xkcd.com/1589/
# Disconnected  >>  xkcd.com/74/
# Connected     >>  xkcd.com/1588/
# Connected     >>  xkcd.com/75/
# Disconnected  >>  xkcd.com/1588/
# Disconnected  >>  xkcd.com/75/
# Connected     >>  xkcd.com/1587/
# Connected     >>  xkcd.com/76/
# Disconnected  >>  xkcd.com/1587/
# Disconnected  >>  xkcd.com/76/
# Connected     >>  xkcd.com/1586/
# Connected     >>  xkcd.com/77/
# Disconnected  >>  xkcd.com/1586/
# Disconnected  >>  xkcd.com/77/
# Connected     >>  xkcd.com/1585/
# Connected     >>  xkcd.com/78/
# Disconnected  >>  xkcd.com/1585/
# Disconnected  >>  xkcd.com/78/
# Connected     >>  xkcd.com/1584/
# Connected     >>  xkcd.com/79/
# Disconnected  >>  xkcd.com/1584/
# Disconnected  >>  xkcd.com/79/
# Connected     >>  xkcd.com/1583/
# Connected     >>  xkcd.com/80/
# Disconnected  >>  xkcd.com/1583/
# Disconnected  >>  xkcd.com/80/
# Connected     >>  xkcd.com/1582/
# Connected     >>  xkcd.com/81/
# Disconnected  >>  xkcd.com/1582/
# Disconnected  >>  xkcd.com/81/
# Connected     >>  xkcd.com/1581/
# Connected     >>  xkcd.com/82/
# Disconnected  >>  xkcd.com/1581/
# Disconnected  >>  xkcd.com/82/
# Connected     >>  xkcd.com/1580/
# Connected     >>  xkcd.com/83/
# Disconnected  >>  xkcd.com/1580/
# Disconnected  >>  xkcd.com/83/
# Connected     >>  xkcd.com/1579/
# Connected     >>  xkcd.com/84/
# Disconnected  >>  xkcd.com/1579/
# Disconnected  >>  xkcd.com/84/
# Connected     >>  xkcd.com/1578/
# Connected     >>  xkcd.com/85/
# Disconnected  >>  xkcd.com/1578/
# Disconnected  >>  xkcd.com/85/
# Connected     >>  xkcd.com/1577/
# Connected     >>  xkcd.com/86/
# Disconnected  >>  xkcd.com/1577/
# Disconnected  >>  xkcd.com/86/
# Connected     >>  xkcd.com/1576/
# Connected     >>  xkcd.com/87/
# Disconnected  >>  xkcd.com/1576/
# Disconnected  >>  xkcd.com/87/
# Connected     >>  xkcd.com/1575/
# Connected     >>  xkcd.com/88/
# Disconnected  >>  xkcd.com/1575/
# Disconnected  >>  xkcd.com/88/
# Connected     >>  xkcd.com/1574/
# Connected     >>  xkcd.com/89/
# Disconnected  >>  xkcd.com/1574/
# Disconnected  >>  xkcd.com/89/
# Connected     >>  xkcd.com/1573/
# Connected     >>  xkcd.com/90/
# Disconnected  >>  xkcd.com/1573/
# Disconnected  >>  xkcd.com/90/
# Connected     >>  xkcd.com/1572/
# Connected     >>  xkcd.com/91/
# Disconnected  >>  xkcd.com/1572/
# Disconnected  >>  xkcd.com/91/
# Connected     >>  xkcd.com/1571/
# Connected     >>  xkcd.com/92/
# Disconnected  >>  xkcd.com/1571/
# Disconnected  >>  xkcd.com/92/
# Connected     >>  xkcd.com/1570/
# Connected     >>  xkcd.com/93/
# Disconnected  >>  xkcd.com/1570/
# Disconnected  >>  xkcd.com/93/
# Connected     >>  xkcd.com/1569/
# Connected     >>  xkcd.com/94/
# Disconnected  >>  xkcd.com/1569/
# Disconnected  >>  xkcd.com/94/
# Connected     >>  xkcd.com/1568/
# Connected     >>  xkcd.com/95/
# Disconnected  >>  xkcd.com/1568/
# Disconnected  >>  xkcd.com/95/
# Connected     >>  xkcd.com/1567/
# Connected     >>  xkcd.com/96/
# Disconnected  >>  xkcd.com/1567/
# Disconnected  >>  xkcd.com/96/
# Connected     >>  xkcd.com/1566/
# Connected     >>  xkcd.com/97/
# Disconnected  >>  xkcd.com/1566/
# Connected     >>  xkcd.com/1565/
# Disconnected  >>  xkcd.com/97/
# Disconnected  >>  xkcd.com/1565/
# Connected     >>  xkcd.com/98/
# Connected     >>  xkcd.com/1564/
# Disconnected  >>  xkcd.com/98/
# Disconnected  >>  xkcd.com/1564/
# Connected     >>  xkcd.com/99/
# Connected     >>  xkcd.com/1563/
# Disconnected  >>  xkcd.com/99/
# Disconnected  >>  xkcd.com/1563/
# Connected     >>  xkcd.com/100/
# Connected     >>  xkcd.com/1562/
# Disconnected  >>  xkcd.com/100/
# Disconnected  >>  xkcd.com/1562/
# Connected     >>  xkcd.com/101/
# Connected     >>  xkcd.com/1561/
# Disconnected  >>  xkcd.com/101/
# Disconnected  >>  xkcd.com/1561/
# Connected     >>  xkcd.com/102/
# Connected     >>  xkcd.com/1560/
# Disconnected  >>  xkcd.com/102/
# Disconnected  >>  xkcd.com/1560/
# Connected     >>  xkcd.com/103/
# Connected     >>  xkcd.com/1559/
# Disconnected  >>  xkcd.com/103/
# Disconnected  >>  xkcd.com/1559/
# Connected     >>  xkcd.com/104/
# Connected     >>  xkcd.com/1558/
# Disconnected  >>  xkcd.com/104/
# Disconnected  >>  xkcd.com/1558/
# Connected     >>  xkcd.com/105/
# Connected     >>  xkcd.com/1557/
# Disconnected  >>  xkcd.com/105/
# Disconnected  >>  xkcd.com/1557/
# Connected     >>  xkcd.com/106/
# Connected     >>  xkcd.com/1556/
# Disconnected  >>  xkcd.com/106/
# Disconnected  >>  xkcd.com/1556/
# Connected     >>  xkcd.com/107/
# Connected     >>  xkcd.com/1555/
# Disconnected  >>  xkcd.com/107/
# Disconnected  >>  xkcd.com/1555/
# Connected     >>  xkcd.com/108/
# Connected     >>  xkcd.com/1554/
# Disconnected  >>  xkcd.com/108/
# Disconnected  >>  xkcd.com/1554/
# Connected     >>  xkcd.com/109/
# Connected     >>  xkcd.com/1553/
# Disconnected  >>  xkcd.com/109/
# Disconnected  >>  xkcd.com/1553/
# Connected     >>  xkcd.com/110/
# Connected     >>  xkcd.com/1552/
# Disconnected  >>  xkcd.com/110/
# Disconnected  >>  xkcd.com/1552/
# Connected     >>  xkcd.com/111/
# Connected     >>  xkcd.com/1551/
# Disconnected  >>  xkcd.com/111/
# Disconnected  >>  xkcd.com/1551/
# Connected     >>  xkcd.com/112/
# Connected     >>  xkcd.com/1550/
# Disconnected  >>  xkcd.com/112/
# Disconnected  >>  xkcd.com/1550/
# Connected     >>  xkcd.com/113/
# Connected     >>  xkcd.com/1549/
# Disconnected  >>  xkcd.com/113/
# Disconnected  >>  xkcd.com/1549/
# Connected     >>  xkcd.com/114/
# Connected     >>  xkcd.com/1548/
# Disconnected  >>  xkcd.com/114/
# Disconnected  >>  xkcd.com/1548/
# Connected     >>  xkcd.com/115/
# Connected     >>  xkcd.com/1547/
# Disconnected  >>  xkcd.com/115/
# Disconnected  >>  xkcd.com/1547/
# Connected     >>  xkcd.com/116/
# Connected     >>  xkcd.com/1546/
# Disconnected  >>  xkcd.com/116/
# Disconnected  >>  xkcd.com/1546/
# Connected     >>  xkcd.com/117/
# Connected     >>  xkcd.com/1545/
# Disconnected  >>  xkcd.com/117/
# Disconnected  >>  xkcd.com/1545/
# Connected     >>  xkcd.com/118/
# Connected     >>  xkcd.com/1544/
# Disconnected  >>  xkcd.com/118/
# Connected     >>  xkcd.com/119/
# Disconnected  >>  xkcd.com/1544/
# Disconnected  >>  xkcd.com/119/
# Connected     >>  xkcd.com/1543/
# Connected     >>  xkcd.com/120/
# Disconnected  >>  xkcd.com/1543/
# Disconnected  >>  xkcd.com/120/
# Connected     >>  xkcd.com/1542/
# Connected     >>  xkcd.com/121/
# Disconnected  >>  xkcd.com/1542/
# Disconnected  >>  xkcd.com/121/
# Connected     >>  xkcd.com/1541/
# Connected     >>  xkcd.com/122/
# Disconnected  >>  xkcd.com/1541/
# Disconnected  >>  xkcd.com/122/
# Connected     >>  xkcd.com/1540/
# Connected     >>  xkcd.com/123/
# Disconnected  >>  xkcd.com/1540/
# Disconnected  >>  xkcd.com/123/
# Connected     >>  xkcd.com/1539/
# Connected     >>  xkcd.com/124/
# Disconnected  >>  xkcd.com/1539/
# Disconnected  >>  xkcd.com/124/
# Connected     >>  xkcd.com/1538/
# Connected     >>  xkcd.com/125/
# Disconnected  >>  xkcd.com/1538/
# Disconnected  >>  xkcd.com/125/
# Connected     >>  xkcd.com/1537/
# Connected     >>  xkcd.com/126/
# Disconnected  >>  xkcd.com/1537/
# Disconnected  >>  xkcd.com/126/
# Connected     >>  xkcd.com/1536/
# Connected     >>  xkcd.com/127/
# Disconnected  >>  xkcd.com/1536/
# Disconnected  >>  xkcd.com/127/
# Connected     >>  xkcd.com/1535/
# Connected     >>  xkcd.com/128/
# Disconnected  >>  xkcd.com/1535/
# Disconnected  >>  xkcd.com/128/
# Connected     >>  xkcd.com/1534/
# Connected     >>  xkcd.com/129/
# Disconnected  >>  xkcd.com/1534/
# Disconnected  >>  xkcd.com/129/
# Connected     >>  xkcd.com/1533/
# Connected     >>  xkcd.com/130/
# Disconnected  >>  xkcd.com/1533/
# Disconnected  >>  xkcd.com/130/
# Connected     >>  xkcd.com/1532/
# Connected     >>  xkcd.com/131/
# Disconnected  >>  xkcd.com/1532/
# Disconnected  >>  xkcd.com/131/
# Connected     >>  xkcd.com/1531/
# Connected     >>  xkcd.com/132/
# Disconnected  >>  xkcd.com/1531/
# Disconnected  >>  xkcd.com/132/
# Connected     >>  xkcd.com/1530/
# Connected     >>  xkcd.com/133/
# Disconnected  >>  xkcd.com/1530/
# Disconnected  >>  xkcd.com/133/
# Connected     >>  xkcd.com/1529/
# Connected     >>  xkcd.com/134/
# Disconnected  >>  xkcd.com/1529/
# Disconnected  >>  xkcd.com/134/
# Connected     >>  xkcd.com/1528/
# Connected     >>  xkcd.com/135/
# Disconnected  >>  xkcd.com/1528/
# Disconnected  >>  xkcd.com/135/
# Connected     >>  xkcd.com/1527/
# Connected     >>  xkcd.com/136/
# Disconnected  >>  xkcd.com/1527/
# Disconnected  >>  xkcd.com/136/
# Connected     >>  xkcd.com/1526/
# Connected     >>  xkcd.com/137/
# Disconnected  >>  xkcd.com/1526/
# Disconnected  >>  xkcd.com/137/
# Connected     >>  xkcd.com/1525/
# Connected     >>  xkcd.com/138/
# Disconnected  >>  xkcd.com/1525/
# Disconnected  >>  xkcd.com/138/
# Connected     >>  xkcd.com/1524/
# Connected     >>  xkcd.com/139/
# Disconnected  >>  xkcd.com/1524/
# Disconnected  >>  xkcd.com/139/
# Connected     >>  xkcd.com/1523/
# Connected     >>  xkcd.com/140/
# Disconnected  >>  xkcd.com/1523/
# Disconnected  >>  xkcd.com/140/
# Connected     >>  xkcd.com/1522/
# Connected     >>  xkcd.com/141/
# Disconnected  >>  xkcd.com/1522/
# Disconnected  >>  xkcd.com/141/
# Connected     >>  xkcd.com/1521/
# Connected     >>  xkcd.com/142/
# Disconnected  >>  xkcd.com/1521/
# Disconnected  >>  xkcd.com/142/
# Connected     >>  xkcd.com/1520/
# Connected     >>  xkcd.com/143/
# Disconnected  >>  xkcd.com/1520/
# Disconnected  >>  xkcd.com/143/
# Connected     >>  xkcd.com/1519/
# Connected     >>  xkcd.com/144/
# Disconnected  >>  xkcd.com/1519/
# Disconnected  >>  xkcd.com/144/
# Connected     >>  xkcd.com/1518/
# Connected     >>  xkcd.com/145/
# Disconnected  >>  xkcd.com/1518/
# Disconnected  >>  xkcd.com/145/
# Connected     >>  xkcd.com/1517/
# Connected     >>  xkcd.com/146/
# Disconnected  >>  xkcd.com/1517/
# Disconnected  >>  xkcd.com/146/
# Connected     >>  xkcd.com/1516/
# Connected     >>  xkcd.com/147/
# Disconnected  >>  xkcd.com/1516/
# Disconnected  >>  xkcd.com/147/
# Connected     >>  xkcd.com/1515/
# Connected     >>  xkcd.com/148/
# Disconnected  >>  xkcd.com/1515/
# Disconnected  >>  xkcd.com/148/
# Connected     >>  xkcd.com/1514/
# Connected     >>  xkcd.com/149/
# Disconnected  >>  xkcd.com/1514/
# Disconnected  >>  xkcd.com/149/
# Connected     >>  xkcd.com/1513/
# Connected     >>  xkcd.com/150/
# Disconnected  >>  xkcd.com/1513/
# Disconnected  >>  xkcd.com/150/
# Connected     >>  xkcd.com/1512/
# Connected     >>  xkcd.com/151/
# Disconnected  >>  xkcd.com/1512/
# Disconnected  >>  xkcd.com/151/
# Connected     >>  xkcd.com/1511/
# Connected     >>  xkcd.com/152/
# Disconnected  >>  xkcd.com/1511/
# Disconnected  >>  xkcd.com/152/
# Connected     >>  xkcd.com/1510/
# Connected     >>  xkcd.com/153/
# Disconnected  >>  xkcd.com/1510/
# Disconnected  >>  xkcd.com/153/
# Connected     >>  xkcd.com/1509/
# Connected     >>  xkcd.com/154/
# Disconnected  >>  xkcd.com/1509/
# Disconnected  >>  xkcd.com/154/
# Connected     >>  xkcd.com/1508/
# Connected     >>  xkcd.com/155/
# Disconnected  >>  xkcd.com/1508/
# Disconnected  >>  xkcd.com/155/
# Connected     >>  xkcd.com/1507/
# Connected     >>  xkcd.com/156/
# Disconnected  >>  xkcd.com/1507/
# Disconnected  >>  xkcd.com/156/
# Connected     >>  xkcd.com/1506/
# Connected     >>  xkcd.com/157/
# Disconnected  >>  xkcd.com/1506/
# Disconnected  >>  xkcd.com/157/
# Connected     >>  xkcd.com//xkcd.com/1506/
# Connected     >>  xkcd.com/1505/
# Connected     >>  xkcd.com/158/
# Disconnected  >>  xkcd.com//xkcd.com/1506/
# Disconnected  >>  xkcd.com/1505/
# Disconnected  >>  xkcd.com/158/
# Connected     >>  xkcd.com/1504/
# Connected     >>  xkcd.com/159/
# Disconnected  >>  xkcd.com/1504/
# Disconnected  >>  xkcd.com/159/
# Connected     >>  xkcd.com/1503/
# Connected     >>  xkcd.com/160/
# Disconnected  >>  xkcd.com/1503/
# Disconnected  >>  xkcd.com/160/
# Connected     >>  xkcd.com/1502/
# Connected     >>  xkcd.com/161/
# Disconnected  >>  xkcd.com/1502/
# Disconnected  >>  xkcd.com/161/
# Connected     >>  xkcd.com/1501/
# Connected     >>  xkcd.com/162/
# Disconnected  >>  xkcd.com/1501/
# Disconnected  >>  xkcd.com/162/
# Connected     >>  xkcd.com/1500/
# Connected     >>  xkcd.com/163/
# Disconnected  >>  xkcd.com/1500/
# Disconnected  >>  xkcd.com/163/
# Connected     >>  xkcd.com/1499/
# Connected     >>  xkcd.com/164/
# Disconnected  >>  xkcd.com/1499/
# Disconnected  >>  xkcd.com/164/
# Connected     >>  xkcd.com/1498/
# Connected     >>  xkcd.com/165/
# Disconnected  >>  xkcd.com/1498/
# Disconnected  >>  xkcd.com/165/
# Connected     >>  xkcd.com/1497/
# Connected     >>  xkcd.com/166/
# Disconnected  >>  xkcd.com/1497/
# Disconnected  >>  xkcd.com/166/
# Connected     >>  xkcd.com/1496/
# Connected     >>  xkcd.com/167/
# Disconnected  >>  xkcd.com/1496/
# Disconnected  >>  xkcd.com/167/
# Connected     >>  xkcd.com/1495/
# Connected     >>  xkcd.com/168/
# Disconnected  >>  xkcd.com/1495/
# Disconnected  >>  xkcd.com/168/
# Connected     >>  xkcd.com/1494/
# Connected     >>  xkcd.com/169/
# Disconnected  >>  xkcd.com/1494/
# Disconnected  >>  xkcd.com/169/
# Connected     >>  xkcd.com/1493/
# Connected     >>  xkcd.com/170/
# Disconnected  >>  xkcd.com/1493/
# Disconnected  >>  xkcd.com/170/
# Connected     >>  xkcd.com/1492/
# Connected     >>  xkcd.com/171/
# Disconnected  >>  xkcd.com/1492/
# Disconnected  >>  xkcd.com/171/
# Connected     >>  xkcd.com/1491/
# Connected     >>  xkcd.com/172/
# Disconnected  >>  xkcd.com/1491/
# Disconnected  >>  xkcd.com/172/
# Connected     >>  xkcd.com/1490/
# Connected     >>  xkcd.com/173/
# Disconnected  >>  xkcd.com/1490/
# Disconnected  >>  xkcd.com/173/
# Connected     >>  xkcd.com/1489/
# Connected     >>  xkcd.com/174/
# Disconnected  >>  xkcd.com/1489/
# Disconnected  >>  xkcd.com/174/
# Connected     >>  xkcd.com/1488/
# Connected     >>  xkcd.com/175/
# Disconnected  >>  xkcd.com/1488/
# Disconnected  >>  xkcd.com/175/
# Connected     >>  xkcd.com/1487/
# Connected     >>  xkcd.com/176/
# Disconnected  >>  xkcd.com/1487/
# Disconnected  >>  xkcd.com/176/
# Connected     >>  xkcd.com/1486/
# Connected     >>  xkcd.com/177/
# Disconnected  >>  xkcd.com/1486/
# Disconnected  >>  xkcd.com/177/
# Connected     >>  xkcd.com/1485/
# Connected     >>  xkcd.com/178/
# Disconnected  >>  xkcd.com/1485/
# Disconnected  >>  xkcd.com/178/
# Connected     >>  xkcd.com/1484/
# Connected     >>  xkcd.com/179/
# Disconnected  >>  xkcd.com/1484/
# Disconnected  >>  xkcd.com/179/
# Connected     >>  xkcd.com/1483/
# Connected     >>  xkcd.com/180/
# Disconnected  >>  xkcd.com/1483/
# Disconnected  >>  xkcd.com/180/
# Connected     >>  xkcd.com/1482/
# Connected     >>  xkcd.com/181/
# Disconnected  >>  xkcd.com/181/
# Disconnected  >>  xkcd.com/1482/
# Connected     >>  xkcd.com/182/
# Connected     >>  xkcd.com/1481/
# Disconnected  >>  xkcd.com/182/
# Disconnected  >>  xkcd.com/1481/
# Connected     >>  xkcd.com/183/
# Connected     >>  xkcd.com/1480/
# Disconnected  >>  xkcd.com/183/
# Disconnected  >>  xkcd.com/1480/
# Connected     >>  xkcd.com/184/
# Connected     >>  xkcd.com/1479/
# Disconnected  >>  xkcd.com/184/
# Disconnected  >>  xkcd.com/1479/
# Connected     >>  xkcd.com/185/
# Connected     >>  xkcd.com/1478/
# Disconnected  >>  xkcd.com/185/
# Disconnected  >>  xkcd.com/1478/
# Connected     >>  xkcd.com/186/
# Connected     >>  xkcd.com/1477/
# Disconnected  >>  xkcd.com/186/
# Disconnected  >>  xkcd.com/1477/
# Connected     >>  xkcd.com/187/
# Connected     >>  xkcd.com/1476/
# Disconnected  >>  xkcd.com/187/
# Disconnected  >>  xkcd.com/1476/
# Connected     >>  xkcd.com/188/
# Connected     >>  xkcd.com/1475/
# Disconnected  >>  xkcd.com/188/
# Disconnected  >>  xkcd.com/1475/
# Connected     >>  xkcd.com/189/
# Connected     >>  xkcd.com/1474/
# Disconnected  >>  xkcd.com/189/
# Connected     >>  xkcd.com/190/
# Disconnected  >>  xkcd.com/1474/
# Connected     >>  xkcd.com/1473/
# Disconnected  >>  xkcd.com/190/
# Disconnected  >>  xkcd.com/1473/
# Connected     >>  xkcd.com/191/
# Connected     >>  xkcd.com/1472/
# Disconnected  >>  xkcd.com/191/
# Disconnected  >>  xkcd.com/1472/
# Connected     >>  xkcd.com/192/
# Connected     >>  xkcd.com/1471/
# Disconnected  >>  xkcd.com/192/
# Disconnected  >>  xkcd.com/1471/
# Connected     >>  xkcd.com/193/
# Connected     >>  xkcd.com/1470/
# Disconnected  >>  xkcd.com/193/
# Connected     >>  xkcd.com/194/
# Disconnected  >>  xkcd.com/1470/
# Connected     >>  xkcd.com/1469/
# Disconnected  >>  xkcd.com/194/
# Disconnected  >>  xkcd.com/1469/
# Connected     >>  xkcd.com/195/
# Connected     >>  xkcd.com/1468/
# Disconnected  >>  xkcd.com/195/
# Disconnected  >>  xkcd.com/1468/
# Connected     >>  xkcd.com/196/
# Connected     >>  xkcd.com/1467/
# Disconnected  >>  xkcd.com/196/
# Disconnected  >>  xkcd.com/1467/
# Connected     >>  xkcd.com/197/
# Connected     >>  xkcd.com/1466/
# Disconnected  >>  xkcd.com/197/
# Disconnected  >>  xkcd.com/1466/
# Connected     >>  xkcd.com/198/
# Connected     >>  xkcd.com/1465/
# Disconnected  >>  xkcd.com/198/
# Disconnected  >>  xkcd.com/1465/
# Connected     >>  xkcd.com/199/
# Connected     >>  xkcd.com/1464/
# Disconnected  >>  xkcd.com/199/
# Disconnected  >>  xkcd.com/1464/
# Connected     >>  xkcd.com/200/
# Connected     >>  xkcd.com/1463/
# Disconnected  >>  xkcd.com/200/
# Disconnected  >>  xkcd.com/1463/
# Connected     >>  xkcd.com/201/
# Connected     >>  xkcd.com/1462/
# Disconnected  >>  xkcd.com/201/
# Disconnected  >>  xkcd.com/1462/
# Connected     >>  xkcd.com/202/
# Connected     >>  xkcd.com/1461/
# Disconnected  >>  xkcd.com/202/
# Disconnected  >>  xkcd.com/1461/
# Connected     >>  xkcd.com/203/
# Connected     >>  xkcd.com/1460/
# Disconnected  >>  xkcd.com/203/
# Disconnected  >>  xkcd.com/1460/
# Connected     >>  xkcd.com/204/
# Connected     >>  xkcd.com/1459/
# Disconnected  >>  xkcd.com/204/
# Disconnected  >>  xkcd.com/1459/
# Connected     >>  xkcd.com/205/
# Connected     >>  xkcd.com/1458/
# Disconnected  >>  xkcd.com/205/
# Disconnected  >>  xkcd.com/1458/
# Connected     >>  xkcd.com/206/
# Connected     >>  xkcd.com/1457/
# Disconnected  >>  xkcd.com/206/
# Disconnected  >>  xkcd.com/1457/
# Connected     >>  xkcd.com/207/
# Connected     >>  xkcd.com/1456/
# Disconnected  >>  xkcd.com/207/
# Connected     >>  xkcd.com/208/
# Disconnected  >>  xkcd.com/1456/
# Connected     >>  xkcd.com/1455/
# Disconnected  >>  xkcd.com/208/
# Connected     >>  xkcd.com/209/
# Disconnected  >>  xkcd.com/1455/
# Connected     >>  xkcd.com/1454/
# Disconnected  >>  xkcd.com/209/
# Disconnected  >>  xkcd.com/1454/
# Connected     >>  xkcd.com/210/
# Connected     >>  xkcd.com/1453/
# Disconnected  >>  xkcd.com/210/
# Connected     >>  xkcd.com/211/
# Disconnected  >>  xkcd.com/1453/
# Disconnected  >>  xkcd.com/211/
# Connected     >>  xkcd.com/1452/
# Connected     >>  xkcd.com/212/
# Disconnected  >>  xkcd.com/1452/
# Disconnected  >>  xkcd.com/212/
# Connected     >>  xkcd.com/1451/
# Connected     >>  xkcd.com/213/
# Disconnected  >>  xkcd.com/1451/
# Disconnected  >>  xkcd.com/213/
# Connected     >>  xkcd.com/1450/
# Connected     >>  xkcd.com/214/
# Disconnected  >>  xkcd.com/1450/
# Disconnected  >>  xkcd.com/214/
# Connected     >>  xkcd.com/1449/
# Connected     >>  xkcd.com/215/
# Disconnected  >>  xkcd.com/1449/
# Connected     >>  xkcd.com/1448/
# Disconnected  >>  xkcd.com/215/
# Disconnected  >>  xkcd.com/1448/
# Connected     >>  xkcd.com/216/
# Connected     >>  xkcd.com/1447/
# Disconnected  >>  xkcd.com/216/
# Disconnected  >>  xkcd.com/1447/
# Connected     >>  xkcd.com/217/
# Connected     >>  xkcd.com/1446/
# Disconnected  >>  xkcd.com/217/
# Disconnected  >>  xkcd.com/1446/
# Connected     >>  xkcd.com/218/
# Connected     >>  xkcd.com/1445/
# Disconnected  >>  xkcd.com/218/
# Disconnected  >>  xkcd.com/1445/
# Connected     >>  xkcd.com/219/
# Connected     >>  xkcd.com/1444/
# Disconnected  >>  xkcd.com/219/
# Disconnected  >>  xkcd.com/1444/
# Connected     >>  xkcd.com/220/
# Connected     >>  xkcd.com/1443/
# Disconnected  >>  xkcd.com/1443/
# Disconnected  >>  xkcd.com/220/
# Connected     >>  xkcd.com/1442/
# Connected     >>  xkcd.com/221/
# Disconnected  >>  xkcd.com/1442/
# Disconnected  >>  xkcd.com/221/
# Connected     >>  xkcd.com/1441/
# Connected     >>  xkcd.com/222/
# Disconnected  >>  xkcd.com/1441/
# Disconnected  >>  xkcd.com/222/
# Connected     >>  xkcd.com/1440/
# Connected     >>  xkcd.com/223/
# Disconnected  >>  xkcd.com/1440/
# Disconnected  >>  xkcd.com/223/
# Connected     >>  xkcd.com/1439/
# Connected     >>  xkcd.com/224/
# Disconnected  >>  xkcd.com/1439/
# Disconnected  >>  xkcd.com/224/
# Connected     >>  xkcd.com/1438/
# Connected     >>  xkcd.com/225/
# Disconnected  >>  xkcd.com/1438/
# Disconnected  >>  xkcd.com/225/
# Connected     >>  xkcd.com/1437/
# Connected     >>  xkcd.com/226/
# Disconnected  >>  xkcd.com/1437/
# Disconnected  >>  xkcd.com/226/
# Connected     >>  xkcd.com/1436/
# Connected     >>  xkcd.com/227/
# Disconnected  >>  xkcd.com/1436/
# Disconnected  >>  xkcd.com/227/
# Connected     >>  xkcd.com/1435/
# Connected     >>  xkcd.com/228/
# Disconnected  >>  xkcd.com/1435/
# Disconnected  >>  xkcd.com/228/
# Connected     >>  xkcd.com/1434/
# Connected     >>  xkcd.com/229/
# Disconnected  >>  xkcd.com/1434/
# Disconnected  >>  xkcd.com/229/
# Connected     >>  xkcd.com/1433/
# Connected     >>  xkcd.com/230/
# Disconnected  >>  xkcd.com/1433/
# Disconnected  >>  xkcd.com/230/
# Connected     >>  xkcd.com/1432/
# Connected     >>  xkcd.com/231/
# Disconnected  >>  xkcd.com/1432/
# Disconnected  >>  xkcd.com/231/
# Connected     >>  xkcd.com/1431/
# Connected     >>  xkcd.com/232/
# Disconnected  >>  xkcd.com/1431/
# Disconnected  >>  xkcd.com/232/
# Connected     >>  xkcd.com/1430/
# Connected     >>  xkcd.com/233/
# Disconnected  >>  xkcd.com/233/
# Disconnected  >>  xkcd.com/1430/
# Connected     >>  xkcd.com/234/
# Connected     >>  xkcd.com/1429/
# Disconnected  >>  xkcd.com/234/
# Connected     >>  xkcd.com/235/
# Disconnected  >>  xkcd.com/1429/
# Disconnected  >>  xkcd.com/235/
# Connected     >>  xkcd.com/1428/
# Connected     >>  xkcd.com/236/
# Disconnected  >>  xkcd.com/1428/
# Disconnected  >>  xkcd.com/236/
# Connected     >>  xkcd.com/1427/
# Connected     >>  xkcd.com/237/
# Disconnected  >>  xkcd.com/1427/
# Disconnected  >>  xkcd.com/237/
# Connected     >>  xkcd.com/1426/
# Connected     >>  xkcd.com/238/
# Disconnected  >>  xkcd.com/1426/
# Disconnected  >>  xkcd.com/238/
# Connected     >>  xkcd.com/1425/
# Connected     >>  xkcd.com/239/
# Disconnected  >>  xkcd.com/1425/
# Disconnected  >>  xkcd.com/239/
# Connected     >>  xkcd.com/1424/
# Connected     >>  xkcd.com/240/
# Disconnected  >>  xkcd.com/1424/
# Disconnected  >>  xkcd.com/240/
# Connected     >>  xkcd.com/1423/
# Connected     >>  xkcd.com/241/
# Disconnected  >>  xkcd.com/1423/
# Disconnected  >>  xkcd.com/241/
# Connected     >>  xkcd.com/1422/
# Connected     >>  xkcd.com/242/
# Disconnected  >>  xkcd.com/1422/
# Disconnected  >>  xkcd.com/242/
# Connected     >>  xkcd.com/1421/
# Connected     >>  xkcd.com/243/
# Disconnected  >>  xkcd.com/1421/
# Disconnected  >>  xkcd.com/243/
# Connected     >>  xkcd.com/1420/
# Connected     >>  xkcd.com/244/
# Disconnected  >>  xkcd.com/1420/
# Disconnected  >>  xkcd.com/244/
# Connected     >>  xkcd.com/1419/
# Connected     >>  xkcd.com/245/
# Disconnected  >>  xkcd.com/1419/
# Disconnected  >>  xkcd.com/245/
# Connected     >>  xkcd.com/1418/
# Connected     >>  xkcd.com/246/
# Disconnected  >>  xkcd.com/1418/
# Disconnected  >>  xkcd.com/246/
# Connected     >>  xkcd.com/1417/
# Connected     >>  xkcd.com/247/
# Disconnected  >>  xkcd.com/1417/
# Disconnected  >>  xkcd.com/247/
# Connected     >>  xkcd.com/1416/
# Connected     >>  xkcd.com/248/
# Disconnected  >>  xkcd.com/1416/
# Disconnected  >>  xkcd.com/248/
# Connected     >>  xkcd.com/1415/
# Connected     >>  xkcd.com/249/
# Disconnected  >>  xkcd.com/1415/
# Disconnected  >>  xkcd.com/249/
# Connected     >>  xkcd.com/1414/
# Connected     >>  xkcd.com/250/
# Disconnected  >>  xkcd.com/1414/
# Disconnected  >>  xkcd.com/250/
# Connected     >>  xkcd.com/1413/
# Connected     >>  xkcd.com/251/
# Disconnected  >>  xkcd.com/1413/
# Disconnected  >>  xkcd.com/251/
# Connected     >>  xkcd.com/1412/
# Connected     >>  xkcd.com/252/
# Disconnected  >>  xkcd.com/1412/
# Disconnected  >>  xkcd.com/252/
# Connected     >>  xkcd.com/1411/
# Connected     >>  xkcd.com/253/
# Disconnected  >>  xkcd.com/1411/
# Disconnected  >>  xkcd.com/253/
# Connected     >>  xkcd.com/1410/
# Connected     >>  xkcd.com/254/
# Disconnected  >>  xkcd.com/1410/
# Disconnected  >>  xkcd.com/254/
# Connected     >>  xkcd.com/1409/
# Connected     >>  xkcd.com/255/
# Disconnected  >>  xkcd.com/1409/
# Disconnected  >>  xkcd.com/255/
# Connected     >>  xkcd.com/1408/
# Connected     >>  xkcd.com/256/
# Disconnected  >>  xkcd.com/1408/
# Disconnected  >>  xkcd.com/256/
# Connected     >>  xkcd.com/1407/
# Connected     >>  xkcd.com/257/
# Disconnected  >>  xkcd.com/1407/
# Disconnected  >>  xkcd.com/257/
# Connected     >>  xkcd.com/1406/
# Connected     >>  xkcd.com/258/
# Disconnected  >>  xkcd.com/1406/
# Disconnected  >>  xkcd.com/258/
# Connected     >>  xkcd.com/1405/
# Connected     >>  xkcd.com/259/
# Disconnected  >>  xkcd.com/1405/
# Disconnected  >>  xkcd.com/259/
# Connected     >>  xkcd.com/1404/
# Connected     >>  xkcd.com/260/
# Disconnected  >>  xkcd.com/1404/
# Disconnected  >>  xkcd.com/260/
# Connected     >>  xkcd.com/1403/
# Connected     >>  xkcd.com/261/
# Disconnected  >>  xkcd.com/1403/
# Disconnected  >>  xkcd.com/261/
# Connected     >>  xkcd.com/1402/
# Connected     >>  xkcd.com/262/
# Disconnected  >>  xkcd.com/1402/
# Disconnected  >>  xkcd.com/262/
# Connected     >>  xkcd.com/1401/
# Connected     >>  xkcd.com/263/
# Disconnected  >>  xkcd.com/1401/
# Disconnected  >>  xkcd.com/263/
# Connected     >>  xkcd.com/1400/
# Connected     >>  xkcd.com/264/
# Disconnected  >>  xkcd.com/1400/
# Connected     >>  xkcd.com/1399/
# Disconnected  >>  xkcd.com/264/
# Disconnected  >>  xkcd.com/1399/
# Connected     >>  xkcd.com/265/
# Connected     >>  xkcd.com/1398/
# Disconnected  >>  xkcd.com/265/
# Disconnected  >>  xkcd.com/1398/
# Connected     >>  xkcd.com/266/
# Connected     >>  xkcd.com/1397/
# Disconnected  >>  xkcd.com/266/
# Disconnected  >>  xkcd.com/1397/
# Connected     >>  xkcd.com/267/
# Connected     >>  xkcd.com/1396/
# Disconnected  >>  xkcd.com/267/
# Disconnected  >>  xkcd.com/1396/
# Connected     >>  xkcd.com/268/
# Connected     >>  xkcd.com/1395/
# Disconnected  >>  xkcd.com/268/
# Disconnected  >>  xkcd.com/1395/
# Connected     >>  xkcd.com/269/
# Connected     >>  xkcd.com/1394/
# Disconnected  >>  xkcd.com/269/
# Disconnected  >>  xkcd.com/1394/
# Connected     >>  xkcd.com/270/
# Connected     >>  xkcd.com/1393/
# Disconnected  >>  xkcd.com/270/
# Disconnected  >>  xkcd.com/1393/
# Connected     >>  xkcd.com/271/
# Connected     >>  xkcd.com/1392/
# Disconnected  >>  xkcd.com/271/
# Disconnected  >>  xkcd.com/1392/
# Connected     >>  xkcd.com/272/
# Connected     >>  xkcd.com/1391/
# Disconnected  >>  xkcd.com/272/
# Disconnected  >>  xkcd.com/1391/
# Connected     >>  xkcd.com/273/
# Connected     >>  xkcd.com/1390/
# Disconnected  >>  xkcd.com/273/
# Disconnected  >>  xkcd.com/1390/
# Connected     >>  xkcd.com/274/
# Connected     >>  xkcd.com/1389/
# Disconnected  >>  xkcd.com/274/
# Disconnected  >>  xkcd.com/1389/
# Connected     >>  xkcd.com/275/
# Connected     >>  xkcd.com/1388/
# Disconnected  >>  xkcd.com/275/
# Disconnected  >>  xkcd.com/1388/
# Connected     >>  xkcd.com/276/
# Connected     >>  xkcd.com/1387/
# Disconnected  >>  xkcd.com/276/
# Disconnected  >>  xkcd.com/1387/
# Connected     >>  xkcd.com/277/
# Connected     >>  xkcd.com/1386/
# Disconnected  >>  xkcd.com/277/
# Disconnected  >>  xkcd.com/1386/
# Connected     >>  xkcd.com/278/
# Connected     >>  xkcd.com/1385/
# Disconnected  >>  xkcd.com/278/
# Disconnected  >>  xkcd.com/1385/
# Connected     >>  xkcd.com/279/
# Connected     >>  xkcd.com/1384/
# Disconnected  >>  xkcd.com/279/
# Disconnected  >>  xkcd.com/1384/
# Connected     >>  xkcd.com/280/
# Connected     >>  xkcd.com/1383/
# Disconnected  >>  xkcd.com/280/
# Disconnected  >>  xkcd.com/1383/
# Connected     >>  xkcd.com/281/
# Connected     >>  xkcd.com/1382/
# Disconnected  >>  xkcd.com/281/
# Disconnected  >>  xkcd.com/1382/
# Connected     >>  xkcd.com/282/
# Connected     >>  xkcd.com/1381/
# Disconnected  >>  xkcd.com/282/
# Disconnected  >>  xkcd.com/1381/
# Connected     >>  xkcd.com/283/
# Connected     >>  xkcd.com/1380/
# Disconnected  >>  xkcd.com/283/
# Disconnected  >>  xkcd.com/1380/
# Connected     >>  xkcd.com/284/
# Connected     >>  xkcd.com/1379/
# Disconnected  >>  xkcd.com/284/
# Disconnected  >>  xkcd.com/1379/
# Connected     >>  xkcd.com/285/
# Connected     >>  xkcd.com/1378/
# Disconnected  >>  xkcd.com/1378/
# Disconnected  >>  xkcd.com/285/
# Connected     >>  xkcd.com/1377/
# Connected     >>  xkcd.com/286/
# Disconnected  >>  xkcd.com/1377/
# Disconnected  >>  xkcd.com/286/
# Connected     >>  xkcd.com/1376/
# Connected     >>  xkcd.com/287/
# Disconnected  >>  xkcd.com/287/
# Disconnected  >>  xkcd.com/1376/
# Connected     >>  xkcd.com/288/
# Connected     >>  xkcd.com/1375/
# Disconnected  >>  xkcd.com/288/
# Disconnected  >>  xkcd.com/1375/
# Connected     >>  xkcd.com/289/
# Connected     >>  xkcd.com/1374/
# Disconnected  >>  xkcd.com/289/
# Disconnected  >>  xkcd.com/1374/
# Connected     >>  xkcd.com/290/
# Connected     >>  xkcd.com/1373/
# Disconnected  >>  xkcd.com/290/
# Disconnected  >>  xkcd.com/1373/
# Connected     >>  xkcd.com/291/
# Connected     >>  xkcd.com/1372/
# Disconnected  >>  xkcd.com/291/
# Disconnected  >>  xkcd.com/1372/
# Connected     >>  xkcd.com/292/
# Connected     >>  xkcd.com/1371/
# Disconnected  >>  xkcd.com/292/
# Disconnected  >>  xkcd.com/1371/
# Connected     >>  xkcd.com/293/
# Connected     >>  xkcd.com/1370/
# Disconnected  >>  xkcd.com/293/
# Disconnected  >>  xkcd.com/1370/
# Connected     >>  xkcd.com/294/
# Connected     >>  xkcd.com/1369/
# Disconnected  >>  xkcd.com/294/
# Disconnected  >>  xkcd.com/1369/
# Connected     >>  xkcd.com/295/
# Connected     >>  xkcd.com/1368/
# Disconnected  >>  xkcd.com/295/
# Disconnected  >>  xkcd.com/1368/
# Connected     >>  xkcd.com/296/
# Connected     >>  xkcd.com/1367/
# Disconnected  >>  xkcd.com/1367/
# Disconnected  >>  xkcd.com/296/
# Connected     >>  xkcd.com/1366/
# Connected     >>  xkcd.com/297/
# Disconnected  >>  xkcd.com/1366/
# Disconnected  >>  xkcd.com/297/
# Connected     >>  xkcd.com/1365/
# Connected     >>  xkcd.com/298/
# Disconnected  >>  xkcd.com/1365/
# Disconnected  >>  xkcd.com/298/
# Connected     >>  xkcd.com/1364/
# Connected     >>  xkcd.com/299/
# Disconnected  >>  xkcd.com/1364/
# Disconnected  >>  xkcd.com/299/
# Connected     >>  xkcd.com/1363/
# Connected     >>  xkcd.com/300/
# Disconnected  >>  xkcd.com/1363/
# Disconnected  >>  xkcd.com/300/
# Connected     >>  xkcd.com/1362/
# Connected     >>  xkcd.com/301/
# Disconnected  >>  xkcd.com/1362/
# Disconnected  >>  xkcd.com/301/
# Connected     >>  xkcd.com/1361/
# Connected     >>  xkcd.com/302/
# Disconnected  >>  xkcd.com/1361/
# Disconnected  >>  xkcd.com/302/
# Connected     >>  xkcd.com/1360/
# Connected     >>  xkcd.com/303/
# Disconnected  >>  xkcd.com/1360/
# Disconnected  >>  xkcd.com/303/
# Connected     >>  xkcd.com/1359/
# Connected     >>  xkcd.com/304/
# Disconnected  >>  xkcd.com/1359/
# Disconnected  >>  xkcd.com/304/
# Connected     >>  xkcd.com/1358/
# Connected     >>  xkcd.com/305/
# Disconnected  >>  xkcd.com/1358/
# Disconnected  >>  xkcd.com/305/
# Connected     >>  xkcd.com/1357/
# Connected     >>  xkcd.com/306/
# Disconnected  >>  xkcd.com/1357/
# Disconnected  >>  xkcd.com/306/
# Connected     >>  xkcd.com/1356/
# Connected     >>  xkcd.com/307/
# Disconnected  >>  xkcd.com/1356/
# Disconnected  >>  xkcd.com/307/
# Connected     >>  xkcd.com/1355/
# Connected     >>  xkcd.com/308/
# Disconnected  >>  xkcd.com/1355/
# Disconnected  >>  xkcd.com/308/
# Connected     >>  xkcd.com/1354/
# Connected     >>  xkcd.com/309/
# Disconnected  >>  xkcd.com/1354/
# Disconnected  >>  xkcd.com/309/
# Connected     >>  xkcd.com/1353/
# Connected     >>  xkcd.com/310/
# Disconnected  >>  xkcd.com/1353/
# Disconnected  >>  xkcd.com/310/
# Connected     >>  xkcd.com/1352/
# Connected     >>  xkcd.com/311/
# Disconnected  >>  xkcd.com/1352/
# Disconnected  >>  xkcd.com/311/
# Connected     >>  xkcd.com/1351/
# Connected     >>  xkcd.com/312/
# Disconnected  >>  xkcd.com/1351/
# Disconnected  >>  xkcd.com/312/
# Connected     >>  xkcd.com/1350/
# Connected     >>  xkcd.com/313/
# Disconnected  >>  xkcd.com/1350/
# Disconnected  >>  xkcd.com/313/
# Connected     >>  xkcd.com/1349/
# Connected     >>  xkcd.com/314/
# Disconnected  >>  xkcd.com/1349/
# Disconnected  >>  xkcd.com/314/
# Connected     >>  xkcd.com/1348/
# Connected     >>  xkcd.com/315/
# Disconnected  >>  xkcd.com/1348/
# Disconnected  >>  xkcd.com/315/
# Connected     >>  xkcd.com/1347/
# Connected     >>  xkcd.com/316/
# Disconnected  >>  xkcd.com/1347/
# Disconnected  >>  xkcd.com/316/
# Connected     >>  xkcd.com/1346/
# Connected     >>  xkcd.com/317/
# Disconnected  >>  xkcd.com/1346/
# Disconnected  >>  xkcd.com/317/
# Connected     >>  xkcd.com/1345/
# Connected     >>  xkcd.com/318/
# Disconnected  >>  xkcd.com/1345/
# Disconnected  >>  xkcd.com/318/
# Connected     >>  xkcd.com/1344/
# Connected     >>  xkcd.com/319/
# Disconnected  >>  xkcd.com/1344/
# Disconnected  >>  xkcd.com/319/
# Connected     >>  xkcd.com/1343/
# Connected     >>  xkcd.com/320/
# Disconnected  >>  xkcd.com/1343/
# Disconnected  >>  xkcd.com/320/
# Connected     >>  xkcd.com/1342/
# Connected     >>  xkcd.com/321/
# Disconnected  >>  xkcd.com/1342/
# Disconnected  >>  xkcd.com/321/
# Connected     >>  xkcd.com/1341/
# Connected     >>  xkcd.com/322/
# Disconnected  >>  xkcd.com/1341/
# Disconnected  >>  xkcd.com/322/
# Connected     >>  xkcd.com/1340/
# Connected     >>  xkcd.com/323/
# Disconnected  >>  xkcd.com/1340/
# Disconnected  >>  xkcd.com/323/
# Connected     >>  xkcd.com/1339/
# Connected     >>  xkcd.com/324/
# Disconnected  >>  xkcd.com/1339/
# Disconnected  >>  xkcd.com/324/
# Connected     >>  xkcd.com/1338/
# Connected     >>  xkcd.com/325/
# Disconnected  >>  xkcd.com/1338/
# Disconnected  >>  xkcd.com/325/
# Connected     >>  xkcd.com/1337/
# Connected     >>  xkcd.com/326/
# Disconnected  >>  xkcd.com/1337/
# Disconnected  >>  xkcd.com/326/
# Connected     >>  xkcd.com/1336/
# Connected     >>  xkcd.com/327/
# Disconnected  >>  xkcd.com/1336/
# Disconnected  >>  xkcd.com/327/
# Connected     >>  xkcd.com/1335/
# Connected     >>  xkcd.com/328/
# Disconnected  >>  xkcd.com/1335/
# Disconnected  >>  xkcd.com/328/
# Connected     >>  xkcd.com/1334/
# Connected     >>  xkcd.com/329/
# Disconnected  >>  xkcd.com/1334/
# Disconnected  >>  xkcd.com/329/
# Connected     >>  xkcd.com/1333/
# Connected     >>  xkcd.com/330/
# Disconnected  >>  xkcd.com/1333/
# Disconnected  >>  xkcd.com/330/
# Connected     >>  xkcd.com/1332/
# Connected     >>  xkcd.com/331/
# Disconnected  >>  xkcd.com/1332/
# Disconnected  >>  xkcd.com/331/
# Connected     >>  xkcd.com/1331/
# Connected     >>  xkcd.com/332/
# Disconnected  >>  xkcd.com/332/
# Disconnected  >>  xkcd.com/1331/
# Connected     >>  xkcd.com/333/
# Connected     >>  xkcd.com/1330/
# Disconnected  >>  xkcd.com/333/
# Disconnected  >>  xkcd.com/1330/
# Connected     >>  xkcd.com/334/
# Connected     >>  xkcd.com/1329/
# Disconnected  >>  xkcd.com/334/
# Disconnected  >>  xkcd.com/1329/
# Connected     >>  xkcd.com/335/
# Connected     >>  xkcd.com/1328/
# Disconnected  >>  xkcd.com/335/
# Disconnected  >>  xkcd.com/1328/
# Connected     >>  xkcd.com/336/
# Connected     >>  xkcd.com/1327/
# Disconnected  >>  xkcd.com/336/
# Disconnected  >>  xkcd.com/1327/
# Connected     >>  xkcd.com/337/
# Connected     >>  xkcd.com/1326/
# Disconnected  >>  xkcd.com/337/
# Disconnected  >>  xkcd.com/1326/
# Connected     >>  xkcd.com/338/
# Connected     >>  xkcd.com/1325/
# Disconnected  >>  xkcd.com/338/
# Disconnected  >>  xkcd.com/1325/
# Connected     >>  xkcd.com/339/
# Connected     >>  xkcd.com/1324/
# Disconnected  >>  xkcd.com/339/
# Disconnected  >>  xkcd.com/1324/
# Connected     >>  xkcd.com/340/
# Connected     >>  xkcd.com/1323/
# Disconnected  >>  xkcd.com/340/
# Disconnected  >>  xkcd.com/1323/
# Connected     >>  xkcd.com/341/
# Connected     >>  xkcd.com/1322/
# Disconnected  >>  xkcd.com/341/
# Disconnected  >>  xkcd.com/1322/
# Connected     >>  xkcd.com/342/
# Connected     >>  xkcd.com/1321/
# Disconnected  >>  xkcd.com/342/
# Disconnected  >>  xkcd.com/1321/
# Connected     >>  xkcd.com/343/
# Connected     >>  xkcd.com/1320/
# Disconnected  >>  xkcd.com/343/
# Disconnected  >>  xkcd.com/1320/
# Connected     >>  xkcd.com/344/
# Connected     >>  xkcd.com/1319/
# Disconnected  >>  xkcd.com/344/
# Disconnected  >>  xkcd.com/1319/
# Connected     >>  xkcd.com/345/
# Connected     >>  xkcd.com/1318/
# Disconnected  >>  xkcd.com/345/
# Disconnected  >>  xkcd.com/1318/
# Connected     >>  xkcd.com/346/
# Connected     >>  xkcd.com/1317/
# Disconnected  >>  xkcd.com/346/
# Disconnected  >>  xkcd.com/1317/
# Connected     >>  xkcd.com/347/
# Connected     >>  xkcd.com/1316/
# Disconnected  >>  xkcd.com/347/
# Disconnected  >>  xkcd.com/1316/
# Connected     >>  xkcd.com/348/
# Connected     >>  xkcd.com/1315/
# Disconnected  >>  xkcd.com/348/
# Disconnected  >>  xkcd.com/1315/
# Connected     >>  xkcd.com/349/
# Connected     >>  xkcd.com/1314/
# Disconnected  >>  xkcd.com/349/
# Disconnected  >>  xkcd.com/1314/
# Connected     >>  xkcd.com/350/
# Connected     >>  xkcd.com/1313/
# Disconnected  >>  xkcd.com/350/
# Disconnected  >>  xkcd.com/1313/
# Connected     >>  xkcd.com/351/
# Connected     >>  xkcd.com/1312/
# Disconnected  >>  xkcd.com/351/
# Disconnected  >>  xkcd.com/1312/
# Connected     >>  xkcd.com/352/
# Connected     >>  xkcd.com/1311/
# Disconnected  >>  xkcd.com/352/
# Disconnected  >>  xkcd.com/1311/
# Connected     >>  xkcd.com/353/
# Connected     >>  xkcd.com/1310/
# Disconnected  >>  xkcd.com/1310/
# Disconnected  >>  xkcd.com/353/
# Connected     >>  xkcd.com/1309/
# Connected     >>  xkcd.com/354/
# Disconnected  >>  xkcd.com/1309/
# Disconnected  >>  xkcd.com/354/
# Connected     >>  xkcd.com/1308/
# Connected     >>  xkcd.com/355/
# Disconnected  >>  xkcd.com/1308/
# Disconnected  >>  xkcd.com/355/
# Connected     >>  xkcd.com/1307/
# Connected     >>  xkcd.com/356/
# Disconnected  >>  xkcd.com/1307/
# Disconnected  >>  xkcd.com/356/
# Connected     >>  xkcd.com/1306/
# Connected     >>  xkcd.com/357/
# Disconnected  >>  xkcd.com/1306/
# Disconnected  >>  xkcd.com/357/
# Connected     >>  xkcd.com/1305/
# Connected     >>  xkcd.com/358/
# Disconnected  >>  xkcd.com/1305/
# Disconnected  >>  xkcd.com/358/
# Connected     >>  xkcd.com/1304/
# Connected     >>  xkcd.com/359/
# Disconnected  >>  xkcd.com/1304/
# Disconnected  >>  xkcd.com/359/
# Connected     >>  xkcd.com/1303/
# Connected     >>  xkcd.com/360/
# Disconnected  >>  xkcd.com/1303/
# Disconnected  >>  xkcd.com/360/
# Connected     >>  xkcd.com/1302/
# Connected     >>  xkcd.com/361/
# Disconnected  >>  xkcd.com/1302/
# Disconnected  >>  xkcd.com/361/
# Connected     >>  xkcd.com/1301/
# Connected     >>  xkcd.com/362/
# Disconnected  >>  xkcd.com/1301/
# Disconnected  >>  xkcd.com/362/
# Connected     >>  xkcd.com/1300/
# Connected     >>  xkcd.com/363/
# Disconnected  >>  xkcd.com/1300/
# Disconnected  >>  xkcd.com/363/
# Connected     >>  xkcd.com/1299/
# Connected     >>  xkcd.com/364/
# Disconnected  >>  xkcd.com/1299/
# Disconnected  >>  xkcd.com/364/
# Connected     >>  xkcd.com/1298/
# Connected     >>  xkcd.com/365/
# Disconnected  >>  xkcd.com/1298/
# Disconnected  >>  xkcd.com/365/
# Connected     >>  xkcd.com/1297/
# Connected     >>  xkcd.com/366/
# Disconnected  >>  xkcd.com/366/
# Disconnected  >>  xkcd.com/1297/
# ...
# Disconnected  >>  xkcd.com/956/
# Disconnected  >>  xkcd.com/706/
# Connected     >>  xkcd.com/955/
# Connected     >>  xkcd.com/707/
# Disconnected  >>  xkcd.com/955/
# Disconnected  >>  xkcd.com/707/
# Connected     >>  xkcd.com/954/
# Connected     >>  xkcd.com/708/
# Disconnected  >>  xkcd.com/954/
# Disconnected  >>  xkcd.com/708/
# Connected     >>  xkcd.com/953/
# Connected     >>  xkcd.com/709/
# Disconnected  >>  xkcd.com/953/
# Disconnected  >>  xkcd.com/709/
# Connected     >>  xkcd.com/952/
# Connected     >>  xkcd.com/710/
# Disconnected  >>  xkcd.com/952/
# Disconnected  >>  xkcd.com/710/
# Connected     >>  xkcd.com/951/
# Connected     >>  xkcd.com/711/
# Disconnected  >>  xkcd.com/951/
# Disconnected  >>  xkcd.com/711/
# Connected     >>  xkcd.com/950/
# Connected     >>  xkcd.com/712/
# Disconnected  >>  xkcd.com/950/
# Disconnected  >>  xkcd.com/712/
# Connected     >>  xkcd.com/949/
# Connected     >>  xkcd.com/713/
# Disconnected  >>  xkcd.com/949/
# Disconnected  >>  xkcd.com/713/
# Connected     >>  xkcd.com/948/
# Connected     >>  xkcd.com/714/
# Disconnected  >>  xkcd.com/948/
# Disconnected  >>  xkcd.com/714/
# Connected     >>  xkcd.com/947/
# Connected     >>  xkcd.com/715/
# Disconnected  >>  xkcd.com/947/
# Disconnected  >>  xkcd.com/715/
# Connected     >>  xkcd.com/946/
# Connected     >>  xkcd.com/716/
# Disconnected  >>  xkcd.com/946/
# Disconnected  >>  xkcd.com/716/
# Connected     >>  xkcd.com/945/
# Connected     >>  xkcd.com/717/
# Disconnected  >>  xkcd.com/945/
# Disconnected  >>  xkcd.com/717/
# Connected     >>  xkcd.com/944/
# Connected     >>  xkcd.com/718/
# Disconnected  >>  xkcd.com/944/
# Disconnected  >>  xkcd.com/718/
# Connected     >>  xkcd.com/943/
# Connected     >>  xkcd.com/719/
# Disconnected  >>  xkcd.com/943/
# Disconnected  >>  xkcd.com/719/
# Connected     >>  xkcd.com/942/
# Connected     >>  xkcd.com/720/
# Disconnected  >>  xkcd.com/942/
# Disconnected  >>  xkcd.com/720/
# Connected     >>  xkcd.com/941/
# Connected     >>  xkcd.com/721/
# Disconnected  >>  xkcd.com/941/
# Disconnected  >>  xkcd.com/721/
# Connected     >>  xkcd.com/940/
# Connected     >>  xkcd.com/722/
# Disconnected  >>  xkcd.com/940/
# Disconnected  >>  xkcd.com/722/
# Connected     >>  xkcd.com/939/
# Connected     >>  xkcd.com/723/
# Disconnected  >>  xkcd.com/939/
# Disconnected  >>  xkcd.com/723/
# Connected     >>  xkcd.com/938/
# Connected     >>  xkcd.com/724/
# Disconnected  >>  xkcd.com/938/
# Connected     >>  xkcd.com/937/
# Disconnected  >>  xkcd.com/724/
# Disconnected  >>  xkcd.com/937/
# Connected     >>  xkcd.com/725/
# Connected     >>  xkcd.com/936/
# Disconnected  >>  xkcd.com/725/
# Disconnected  >>  xkcd.com/936/
# Connected     >>  xkcd.com/726/
# Connected     >>  xkcd.com/935/
# Disconnected  >>  xkcd.com/726/
# Disconnected  >>  xkcd.com/935/
# Connected     >>  xkcd.com/727/
# Connected     >>  xkcd.com/934/
# Disconnected  >>  xkcd.com/727/
# Disconnected  >>  xkcd.com/934/
# Connected     >>  xkcd.com/728/
# Connected     >>  xkcd.com/933/
# Disconnected  >>  xkcd.com/728/
# Disconnected  >>  xkcd.com/933/
# Connected     >>  xkcd.com/729/
# Connected     >>  xkcd.com/932/
# Disconnected  >>  xkcd.com/729/
# Disconnected  >>  xkcd.com/932/
# Connected     >>  xkcd.com/730/
# Connected     >>  xkcd.com/931/
# Disconnected  >>  xkcd.com/730/
# Disconnected  >>  xkcd.com/931/
# Connected     >>  xkcd.com/731/
# Connected     >>  xkcd.com/930/
# Disconnected  >>  xkcd.com/731/
# Disconnected  >>  xkcd.com/930/
# Connected     >>  xkcd.com/732/
# Connected     >>  xkcd.com/929/
# Disconnected  >>  xkcd.com/732/
# Disconnected  >>  xkcd.com/929/
# Connected     >>  xkcd.com/733/
# Connected     >>  xkcd.com/928/
# Disconnected  >>  xkcd.com/733/
# Disconnected  >>  xkcd.com/928/
# Connected     >>  xkcd.com/734/
# Connected     >>  xkcd.com/927/
# Disconnected  >>  xkcd.com/734/
# Disconnected  >>  xkcd.com/927/
# Connected     >>  xkcd.com/735/
# Connected     >>  xkcd.com/926/
# Disconnected  >>  xkcd.com/735/
# Disconnected  >>  xkcd.com/926/
# Connected     >>  xkcd.com/736/
# Connected     >>  xkcd.com/925/
# Disconnected  >>  xkcd.com/736/
# Disconnected  >>  xkcd.com/925/
# Connected     >>  xkcd.com/737/
# Connected     >>  xkcd.com/924/
# Disconnected  >>  xkcd.com/737/
# Disconnected  >>  xkcd.com/924/
# Connected     >>  xkcd.com/738/
# Connected     >>  xkcd.com/923/
# Disconnected  >>  xkcd.com/738/
# Disconnected  >>  xkcd.com/923/
# Connected     >>  xkcd.com/739/
# Connected     >>  xkcd.com/922/
# Disconnected  >>  xkcd.com/739/
# Disconnected  >>  xkcd.com/922/
# Connected     >>  xkcd.com/740/
# Connected     >>  xkcd.com/921/
# Disconnected  >>  xkcd.com/740/
# Disconnected  >>  xkcd.com/921/
# Connected     >>  xkcd.com/741/
# Connected     >>  xkcd.com/920/
# Disconnected  >>  xkcd.com/741/
# Disconnected  >>  xkcd.com/920/
# Connected     >>  xkcd.com/742/
# Connected     >>  xkcd.com/919/
# Disconnected  >>  xkcd.com/742/
# Disconnected  >>  xkcd.com/919/
# Connected     >>  xkcd.com/743/
# Connected     >>  xkcd.com/918/
# Disconnected  >>  xkcd.com/743/
# Disconnected  >>  xkcd.com/918/
# Connected     >>  xkcd.com/744/
# Connected     >>  xkcd.com/917/
# Disconnected  >>  xkcd.com/744/
# Disconnected  >>  xkcd.com/917/
# Connected     >>  xkcd.com/745/
# Connected     >>  xkcd.com/916/
# Disconnected  >>  xkcd.com/745/
# Disconnected  >>  xkcd.com/916/
# Connected     >>  xkcd.com/746/
# Connected     >>  xkcd.com/915/
# Disconnected  >>  xkcd.com/746/
# Disconnected  >>  xkcd.com/915/
# Connected     >>  xkcd.com/747/
# Connected     >>  xkcd.com/914/
# Disconnected  >>  xkcd.com/747/
# Disconnected  >>  xkcd.com/914/
# Connected     >>  xkcd.com/748/
# Connected     >>  xkcd.com/913/
# Disconnected  >>  xkcd.com/748/
# Disconnected  >>  xkcd.com/913/
# Connected     >>  xkcd.com/749/
# Connected     >>  xkcd.com/912/
# Disconnected  >>  xkcd.com/749/
# Disconnected  >>  xkcd.com/912/
# Connected     >>  xkcd.com/750/
# Connected     >>  xkcd.com/911/
# Disconnected  >>  xkcd.com/750/
# Disconnected  >>  xkcd.com/911/
# Connected     >>  xkcd.com/751/
# Connected     >>  xkcd.com/910/
# Disconnected  >>  xkcd.com/751/
# Disconnected  >>  xkcd.com/910/
# Connected     >>  xkcd.com/752/
# Connected     >>  xkcd.com/909/
# Disconnected  >>  xkcd.com/752/
# Connected     >>  xkcd.com/753/
# Disconnected  >>  xkcd.com/909/
# Disconnected  >>  xkcd.com/753/
# Connected     >>  xkcd.com/908/
# Connected     >>  xkcd.com/754/
# Disconnected  >>  xkcd.com/908/
# Disconnected  >>  xkcd.com/754/
# Connected     >>  xkcd.com/907/
# Connected     >>  xkcd.com/755/
# Disconnected  >>  xkcd.com/907/
# Disconnected  >>  xkcd.com/755/
# Connected     >>  xkcd.com/906/
# Connected     >>  xkcd.com/756/
# Disconnected  >>  xkcd.com/906/
# Disconnected  >>  xkcd.com/756/
# Connected     >>  xkcd.com/905/
# Connected     >>  xkcd.com/757/
# Disconnected  >>  xkcd.com/905/
# Disconnected  >>  xkcd.com/757/
# Connected     >>  xkcd.com/904/
# Connected     >>  xkcd.com/758/
# Disconnected  >>  xkcd.com/904/
# Disconnected  >>  xkcd.com/758/
# Connected     >>  xkcd.com/903/
# Connected     >>  xkcd.com/759/
# Disconnected  >>  xkcd.com/903/
# Disconnected  >>  xkcd.com/759/
# Connected     >>  xkcd.com/902/
# Connected     >>  xkcd.com/760/
# Disconnected  >>  xkcd.com/902/
# Disconnected  >>  xkcd.com/760/
# Connected     >>  xkcd.com/901/
# Connected     >>  xkcd.com/761/
# Disconnected  >>  xkcd.com/901/
# Disconnected  >>  xkcd.com/761/
# Connected     >>  xkcd.com/900/
# Connected     >>  xkcd.com/762/
# Disconnected  >>  xkcd.com/900/
# Connected     >>  xkcd.com/899/
# Disconnected  >>  xkcd.com/762/
# Connected     >>  xkcd.com/763/
# Disconnected  >>  xkcd.com/899/
# Connected     >>  xkcd.com/898/
# Disconnected  >>  xkcd.com/763/
# Disconnected  >>  xkcd.com/898/
# Connected     >>  xkcd.com/764/
# Connected     >>  xkcd.com/897/
# Disconnected  >>  xkcd.com/764/
# Disconnected  >>  xkcd.com/897/
# Connected     >>  xkcd.com/765/
# Connected     >>  xkcd.com/896/
# Disconnected  >>  xkcd.com/765/
# Disconnected  >>  xkcd.com/896/
# Connected     >>  xkcd.com/766/
# Connected     >>  xkcd.com/895/
# Disconnected  >>  xkcd.com/766/
# Disconnected  >>  xkcd.com/895/
# Connected     >>  xkcd.com/767/
# Connected     >>  xkcd.com/894/
# Disconnected  >>  xkcd.com/767/
# Disconnected  >>  xkcd.com/894/
# Connected     >>  xkcd.com/768/
# Connected     >>  xkcd.com/893/
# Disconnected  >>  xkcd.com/768/
# Disconnected  >>  xkcd.com/893/
# Connected     >>  xkcd.com/769/
# Connected     >>  xkcd.com/892/
# Disconnected  >>  xkcd.com/769/
# Disconnected  >>  xkcd.com/892/
# Connected     >>  xkcd.com/770/
# Connected     >>  xkcd.com/891/
# Disconnected  >>  xkcd.com/770/
# Disconnected  >>  xkcd.com/891/
# Connected     >>  xkcd.com/771/
# Connected     >>  xkcd.com/890/
# Disconnected  >>  xkcd.com/771/
# Disconnected  >>  xkcd.com/890/
# Connected     >>  xkcd.com/772/
# Connected     >>  xkcd.com/889/
# Disconnected  >>  xkcd.com/772/
# Disconnected  >>  xkcd.com/889/
# Connected     >>  xkcd.com/773/
# Connected     >>  xkcd.com/888/
# Disconnected  >>  xkcd.com/773/
# Disconnected  >>  xkcd.com/888/
# Connected     >>  xkcd.com/774/
# Connected     >>  xkcd.com/887/
# Disconnected  >>  xkcd.com/774/
# Disconnected  >>  xkcd.com/887/
# Connected     >>  xkcd.com/775/
# Connected     >>  xkcd.com/886/
# Disconnected  >>  xkcd.com/775/
# Disconnected  >>  xkcd.com/886/
# Connected     >>  xkcd.com/776/
# Connected     >>  xkcd.com/885/
# Disconnected  >>  xkcd.com/885/
# Disconnected  >>  xkcd.com/776/
# Connected     >>  xkcd.com/884/
# Connected     >>  xkcd.com/777/
# Disconnected  >>  xkcd.com/884/
# Disconnected  >>  xkcd.com/777/
# Connected     >>  xkcd.com/883/
# Connected     >>  xkcd.com/778/
# Disconnected  >>  xkcd.com/883/
# Disconnected  >>  xkcd.com/778/
# Connected     >>  xkcd.com/882/
# Connected     >>  xkcd.com/779/
# Disconnected  >>  xkcd.com/882/
# Disconnected  >>  xkcd.com/779/
# Connected     >>  xkcd.com/881/
# Connected     >>  xkcd.com/780/
# Disconnected  >>  xkcd.com/881/
# Disconnected  >>  xkcd.com/780/
# Connected     >>  xkcd.com/880/
# Connected     >>  xkcd.com/781/
# Disconnected  >>  xkcd.com/880/
# Disconnected  >>  xkcd.com/781/
# Connected     >>  xkcd.com/879/
# Connected     >>  xkcd.com/782/
# Disconnected  >>  xkcd.com/879/
# Disconnected  >>  xkcd.com/782/
# Connected     >>  xkcd.com/878/
# Connected     >>  xkcd.com/783/
# Disconnected  >>  xkcd.com/878/
# Disconnected  >>  xkcd.com/783/
# Connected     >>  xkcd.com/877/
# Connected     >>  xkcd.com/784/
# Disconnected  >>  xkcd.com/877/
# Disconnected  >>  xkcd.com/784/
# Connected     >>  xkcd.com/876/
# Connected     >>  xkcd.com/785/
# Disconnected  >>  xkcd.com/876/
# Disconnected  >>  xkcd.com/785/
# Connected     >>  xkcd.com/875/
# Connected     >>  xkcd.com/786/
# Disconnected  >>  xkcd.com/875/
# Disconnected  >>  xkcd.com/786/
# Connected     >>  xkcd.com/874/
# Connected     >>  xkcd.com/787/
# Disconnected  >>  xkcd.com/874/
# Disconnected  >>  xkcd.com/787/
# Connected     >>  xkcd.com/873/
# Connected     >>  xkcd.com/788/
# Disconnected  >>  xkcd.com/873/
# Disconnected  >>  xkcd.com/788/
# Connected     >>  xkcd.com/872/
# Connected     >>  xkcd.com/789/
# Disconnected  >>  xkcd.com/872/
# Disconnected  >>  xkcd.com/789/
# Connected     >>  xkcd.com/871/
# Connected     >>  xkcd.com/790/
# Disconnected  >>  xkcd.com/871/
# Connected     >>  xkcd.com/870/
# Disconnected  >>  xkcd.com/790/
# Disconnected  >>  xkcd.com/870/
# Connected     >>  xkcd.com/791/
# Connected     >>  xkcd.com/869/
# Disconnected  >>  xkcd.com/791/
# Disconnected  >>  xkcd.com/869/
# Connected     >>  xkcd.com/792/
# Connected     >>  xkcd.com/868/
# Disconnected  >>  xkcd.com/792/
# Disconnected  >>  xkcd.com/868/
# Connected     >>  xkcd.com/793/
# Connected     >>  xkcd.com/867/
# Disconnected  >>  xkcd.com/793/
# Disconnected  >>  xkcd.com/867/
# Connected     >>  xkcd.com/794/
# Connected     >>  xkcd.com/866/
# Disconnected  >>  xkcd.com/794/
# Disconnected  >>  xkcd.com/866/
# Connected     >>  xkcd.com/795/
# Connected     >>  xkcd.com/865/
# Disconnected  >>  xkcd.com/795/
# Disconnected  >>  xkcd.com/865/
# Connected     >>  xkcd.com/796/
# Connected     >>  xkcd.com/864/
# Disconnected  >>  xkcd.com/796/
# Disconnected  >>  xkcd.com/864/
# Connected     >>  xkcd.com/797/
# Connected     >>  xkcd.com/863/
# Disconnected  >>  xkcd.com/797/
# Disconnected  >>  xkcd.com/863/
# Connected     >>  xkcd.com/798/
# Connected     >>  xkcd.com/862/
# Disconnected  >>  xkcd.com/798/
# Disconnected  >>  xkcd.com/862/
# Connected     >>  xkcd.com/799/
# Connected     >>  xkcd.com/861/
# Disconnected  >>  xkcd.com/799/
# Disconnected  >>  xkcd.com/861/
# Connected     >>  xkcd.com/800/
# Connected     >>  xkcd.com/860/
# Disconnected  >>  xkcd.com/800/
# Connected     >>  xkcd.com/801/
# Disconnected  >>  xkcd.com/860/
# Disconnected  >>  xkcd.com/801/
# Connected     >>  xkcd.com/859/
# Connected     >>  xkcd.com/802/
# Disconnected  >>  xkcd.com/859/
# Disconnected  >>  xkcd.com/802/
# Connected     >>  xkcd.com/858/
# Connected     >>  xkcd.com/803/
# Disconnected  >>  xkcd.com/858/
# Disconnected  >>  xkcd.com/803/
# Connected     >>  xkcd.com/857/
# Connected     >>  xkcd.com/804/
# Disconnected  >>  xkcd.com/857/
# Disconnected  >>  xkcd.com/804/
# Connected     >>  xkcd.com/856/
# Connected     >>  xkcd.com/805/
# Disconnected  >>  xkcd.com/856/
# Disconnected  >>  xkcd.com/805/
# Connected     >>  xkcd.com/855/
# Connected     >>  xkcd.com/806/
# Disconnected  >>  xkcd.com/855/
# Disconnected  >>  xkcd.com/806/
# Connected     >>  xkcd.com/854/
# Connected     >>  xkcd.com/807/
# Disconnected  >>  xkcd.com/854/
# Disconnected  >>  xkcd.com/807/
# Connected     >>  xkcd.com/853/
# Connected     >>  xkcd.com/808/
# Disconnected  >>  xkcd.com/853/
# Disconnected  >>  xkcd.com/808/
# Connected     >>  xkcd.com/852/
# Connected     >>  xkcd.com/809/
# Disconnected  >>  xkcd.com/852/
# Disconnected  >>  xkcd.com/809/
# Connected     >>  xkcd.com/851/
# Connected     >>  xkcd.com/810/
# Disconnected  >>  xkcd.com/851/
# Disconnected  >>  xkcd.com/810/
# Connected     >>  xkcd.com/850/
# Connected     >>  xkcd.com/811/
# Disconnected  >>  xkcd.com/850/
# Disconnected  >>  xkcd.com/811/
# Connected     >>  xkcd.com/849/
# Connected     >>  xkcd.com/812/
# Disconnected  >>  xkcd.com/849/
# Connected     >>  xkcd.com/848/
# Disconnected  >>  xkcd.com/812/
# Connected     >>  xkcd.com/813/
# Disconnected  >>  xkcd.com/848/
# Connected     >>  xkcd.com/847/
# Disconnected  >>  xkcd.com/813/
# Disconnected  >>  xkcd.com/847/
# Connected     >>  xkcd.com/814/
# Connected     >>  xkcd.com/846/
# Disconnected  >>  xkcd.com/814/
# Disconnected  >>  xkcd.com/846/
# Connected     >>  xkcd.com/815/
# Connected     >>  xkcd.com/845/
# Disconnected  >>  xkcd.com/815/
# Disconnected  >>  xkcd.com/845/
# Connected     >>  xkcd.com/816/
# Connected     >>  xkcd.com/844/
# Disconnected  >>  xkcd.com/816/
# Disconnected  >>  xkcd.com/844/
# Connected     >>  xkcd.com/817/
# Connected     >>  xkcd.com/843/
# Disconnected  >>  xkcd.com/817/
# Disconnected  >>  xkcd.com/843/
# Connected     >>  xkcd.com/818/
# Connected     >>  xkcd.com/842/
# Disconnected  >>  xkcd.com/818/
# Disconnected  >>  xkcd.com/842/
# Connected     >>  xkcd.com/819/
# Connected     >>  xkcd.com/841/
# Disconnected  >>  xkcd.com/819/
# Disconnected  >>  xkcd.com/841/
# Connected     >>  xkcd.com/820/
# Connected     >>  xkcd.com/840/
# Disconnected  >>  xkcd.com/820/
# Disconnected  >>  xkcd.com/840/
# Connected     >>  xkcd.com/821/
# Connected     >>  xkcd.com/839/
# Disconnected  >>  xkcd.com/821/
# Disconnected  >>  xkcd.com/839/
# Connected     >>  xkcd.com/822/
# Connected     >>  xkcd.com/838/
# Disconnected  >>  xkcd.com/822/
# Disconnected  >>  xkcd.com/838/
# Connected     >>  xkcd.com/823/
# Connected     >>  xkcd.com/837/
# Disconnected  >>  xkcd.com/823/
# Disconnected  >>  xkcd.com/837/
# Connected     >>  xkcd.com/824/
# Connected     >>  xkcd.com/836/
# Disconnected  >>  xkcd.com/824/
# Disconnected  >>  xkcd.com/836/
# Connected     >>  xkcd.com/825/
# Connected     >>  xkcd.com/835/
# Disconnected  >>  xkcd.com/825/
# Disconnected  >>  xkcd.com/835/
# Connected     >>  xkcd.com/826/
# Connected     >>  xkcd.com/834/
# Disconnected  >>  xkcd.com/834/
# Disconnected  >>  xkcd.com/826/
# Connected     >>  xkcd.com/833/
# Connected     >>  xkcd.com/827/
# Disconnected  >>  xkcd.com/833/
# Disconnected  >>  xkcd.com/827/
# Connected     >>  xkcd.com/832/
# Connected     >>  xkcd.com/828/
# Disconnected  >>  xkcd.com/832/
# Disconnected  >>  xkcd.com/828/
# Connected     >>  xkcd.com/831/
# Connected     >>  xkcd.com/829/
# Disconnected  >>  xkcd.com/831/
# Disconnected  >>  xkcd.com/829/
# Connected     >>  xkcd.com/830/
# Disconnected  >>  xkcd.com/830/
